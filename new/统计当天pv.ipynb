# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
from scipy.stats import norm, skew #加载一些统计的库
import time
import gc

# %%
def time2cov(time_):
    '''
    时间是根据天数推移，所以日期为脱敏，但是时间本身不脱敏
    :param time_: 
    :return: 
    '''
    return time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(time_))

# %%
def pre_process(data):
    '''
    :param data: 
    :return: 
    '''

    print('item_category_list_ing')
    for i in range(3):
        data['category_%d'%(i)] = data['item_category_list'].apply(
            lambda x:x.split(";")[i] if len(x.split(";")) > i else " "
        )
    del data['item_category_list']

    print('item_property_list_ing')
    for i in range(3):
        data['property_%d'%(i)] = data['item_property_list'].apply(
            lambda x:x.split(";")[i] if len(x.split(";")) > i else " "
        )
    del data['item_property_list']
    
    print('context_timestamp_ing')
    data['context_timestamp'] = data['context_timestamp'].apply(time2cov)
    
    return data

# %%
def pv(day):
    print(day)
    print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time())))
    data = pd.read_table(day + '.txt',sep=' ',index_col=False)
    data = pre_process(data)
    data = data.sort_values('context_timestamp')
    datatemp = []
    data['category_1_first']=0
    data['category_1_last']=0
    for name,num in data[['user_id','category_1','instance_id','context_timestamp','category_1_first','category_1_last']].groupby(['user_id','category_1']):
        num = num.reset_index().set_index(['index']).sort_values('context_timestamp')
        num =num.reset_index() 
        num =num.reset_index()
        temp = np.array(num.copy()).reshape(-1,8).tolist()
        temp[0][-2]=1
        temp[-1][-1]=1
        datatemp.extend(temp)
    #     print(np.array(num.copy()).reshape(-1,6))
#     print(datatemp.shape)
    print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time())))
    datatemp = pd.DataFrame(datatemp,columns=['category_1_pvnum','index','user_id','category_1','instance_id','context_timestamp','category_1_first','category_1_last'])
    datatemp[['instance_id','category_1_pvnum','category_1_first','category_1_last']].to_csv(day + '_user_clickpv.csv',index=False )
    del(datatemp)
    gc.collect()
    
    datatemp = []
    data['property_0_first']=0
    data['property_0_last']=0
    for name,num in data[['user_id','property_0','instance_id','context_timestamp','property_0_first','property_0_last']].groupby(['user_id','property_0']):
        num = num.reset_index().set_index(['index']).sort_values('context_timestamp')
        num =num.reset_index() 
        num =num.reset_index()
        temp = np.array(num.copy()).reshape(-1,8).tolist()
        temp[0][-2]=1
        temp[-1][-1]=1
        datatemp.extend(temp)
    #     print(np.array(num.copy()).reshape(-1,6))
#     print(datatemp.shape)
    print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time())))
    datatemp = pd.DataFrame(datatemp,columns=['property_0_pvnum','index','user_id','property_0','instance_id','context_timestamp','property_0_first','property_0_last'])
    datatemp[['instance_id','property_0_pvnum','property_0_first','property_0_last']].to_csv(day + '_property_0_pvnum.csv',index=False )
    del(datatemp)
    gc.collect()
    
    datatemp = []
    data['property_1_first']=0
    data['property_1_last']=0
    for name,num in data[['user_id','property_1','instance_id','context_timestamp','property_1_first','property_1_last']].groupby(['user_id','property_1']):
        num = num.reset_index().set_index(['index']).sort_values('context_timestamp')
        num =num.reset_index() 
        num =num.reset_index()
        temp = np.array(num.copy()).reshape(-1,8).tolist()
        temp[0][-2]=1
        temp[-1][-1]=1
        datatemp.extend(temp)
    #     print(np.array(num.copy()).reshape(-1,6))
#     print(datatemp.shape)
    print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time())))
    datatemp = pd.DataFrame(datatemp,columns=['property_1_pvnum','index','user_id','property_1','instance_id','context_timestamp','property_1_first','property_1_last'])
    datatemp[['instance_id','property_1_pvnum','property_1_first','property_1_last']].to_csv(day + '_property_1_pvnum.csv',index=False )
    del(datatemp)
    gc.collect()
    
    datatemp = []
    data['item_id_first']=0
    data['item_id_last']=0
    for name,num in data[['user_id','item_id','instance_id','context_timestamp','item_id_first','item_id_last']].groupby(['user_id','item_id']):
        num = num.reset_index().set_index(['index']).sort_values('context_timestamp')
        num =num.reset_index() 
        num =num.reset_index()
        temp = np.array(num.copy()).reshape(-1,8).tolist()
        temp[0][-2]=1
        temp[-1][-1]=1
        datatemp.extend(temp)
    #     print(np.array(num.copy()).reshape(-1,6))
#     print(datatemp.shape)
    print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time())))
    datatemp = pd.DataFrame(datatemp,columns=['item_id_pvnum','index','user_id','item_id','instance_id','context_timestamp','item_id_first','item_id_last'])
    datatemp[['instance_id','item_id_pvnum','item_id_first','item_id_last']].to_csv(day + '_item_id_pvnum.csv',index=False )
    del(datatemp)
    gc.collect()
    
    del(data)
    gc.collect()

# %%
# daylist = ['day_1','day_2','day_3','day_4','day_5','day_6','day_31']
daylist = ['day_1','day_2']

# %%
print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time())))
# Out:
# 2018-04-28 21:53:22

# %%
for i in daylist:
    pv(i)
# Out:
# day_1
# 2018-04-28 21:53:26
# item_category_list_ing
# item_property_list_ing
# context_timestamp_ing
# 2018-04-28 22:37:50
# 2018-04-28 23:28:45
# 2018-04-29 00:28:14
# 2018-04-29 01:43:23
# day_2
# 2018-04-29 01:43:36
# item_category_list_ing
# item_property_list_ing
# context_timestamp_ing
# 2018-04-29 02:24:52
# 2018-04-29 03:10:03
# 2018-04-29 04:01:39
# 2018-04-29 05:05:59

# %%
day = 'day_1'

# %%
data = pd.read_table(day + '.txt',sep=' ',index_col=False)

# %%
data = pre_process(data)
# Out:
# item_category_list_ing
# item_property_list_ing
# context_timestamp_ing

# %%
data = data.sort_values('context_timestamp')

# %%
data[['context_timestamp']]
# Out:
#            context_timestamp
# 191534   2018-09-01 00:00:00
# 1272935  2018-09-01 00:00:00
# 110224   2018-09-01 00:00:00
# 325911   2018-09-01 00:00:00
# 702444   2018-09-01 00:00:00
# 345331   2018-09-01 00:00:00
# 455111   2018-09-01 00:00:00
# 695695   2018-09-01 00:00:00
# 116861   2018-09-01 00:00:00
# 422940   2018-09-01 00:00:00
# 1040729  2018-09-01 00:00:00
# 629993   2018-09-01 00:00:00
# 80026    2018-09-01 00:00:00
# 1002076  2018-09-01 00:00:01
# 155598   2018-09-01 00:00:01
# 1326009  2018-09-01 00:00:01
# 100387   2018-09-01 00:00:01
# 404680   2018-09-01 00:00:01
# 1261975  2018-09-01 00:00:01
# 79589    2018-09-01 00:00:01
# 1298266  2018-09-01 00:00:01
# 1172143  2018-09-01 00:00:01
# 469621   2018-09-01 00:00:01
# 311631   2018-09-01 00:00:01
# 478736   2018-09-01 00:00:01
# 1155475  2018-09-01 00:00:02
# 182221   2018-09-01 00:00:02
# 576667   2018-09-01 00:00:02
# 652113   2018-09-01 00:00:02
# 432356   2018-09-01 00:00:02
# ...                      ...
# 1026568  2018-09-01 23:59:46
# 746507   2018-09-01 23:59:46
# 1149068  2018-09-01 23:59:46
# 521363   2018-09-01 23:59:46
# 1267645  2018-09-01 23:59:46
# 516170   2018-09-01 23:59:46
# 1192077  2018-09-01 23:59:47
# 183684   2018-09-01 23:59:47
# 538051   2018-09-01 23:59:48
# 48695    2018-09-01 23:59:48
# 1189759  2018-09-01 23:59:48
# 477007   2018-09-01 23:59:48
# 940709   2018-09-01 23:59:49
# 558983   2018-09-01 23:59:49
# 857134   2018-09-01 23:59:49
# 57419    2018-09-01 23:59:49
# 91583    2018-09-01 23:59:49
# 1180221  2018-09-01 23:59:49
# 1332235  2018-09-01 23:59:49
# 439550   2018-09-01 23:59:50
# 1313578  2018-09-01 23:59:50
# 1083093  2018-09-01 23:59:51
# 901826   2018-09-01 23:59:51
# 12460    2018-09-01 23:59:52
# 6476     2018-09-01 23:59:53
# 866174   2018-09-01 23:59:53
# 25071    2018-09-01 23:59:54
# 538578   2018-09-01 23:59:55
# 813149   2018-09-01 23:59:55
# 909776   2018-09-01 23:59:56
#
# [1340697 rows x 1 columns]

# %%
datatemp = []
data['category_1_first']=0
data['category_1_last']=0
for name,num in data[['user_id','category_1','instance_id','context_timestamp','category_1_first','category_1_last']].groupby(['user_id','category_1']):
    num = num.reset_index().set_index(['index']).sort_values('context_timestamp')
    num =num.reset_index() 
    num =num.reset_index()
#     print(type(datatemp))
    temp = np.array(num.copy()).reshape(-1,8).tolist()
    temp[0][-2]=1
    temp[-1][-1]=1
    datatemp.extend(temp)
#     print(np.array(num.copy()).reshape(-1,6).tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-13aea1af6433> in <module>()
#       3 data['category_1_last']=0
#       4 for name,num in data[['user_id','category_1','instance_id','context_timestamp','category_1_first','category_1_last']].groupby(['user_id','category_1']):
# ----> 5     num = num.reset_index().set_index(['index']).sort_values('context_timestamp')
#       6     num =num.reset_index()
#       7     num =num.reset_index()
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2841
#    2842         for c in to_remove:
# -> 2843             del frame[c]
#    2844
#    2845         # clear up memory usage
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    1899             # there was no match, this call should raise the appropriate
#    1900             # exception:
# -> 1901             self._data.delete(key)
#    1902
#    1903         # delete from the caches
#
# D:\anaconda\lib\site-packages\pandas\core\internals.py in delete(self, item)
#    3679                             if not is_blk_deleted[blkno])
#    3680         self._shape = None
# -> 3681         self._rebuild_blknos_and_blklocs()
#    3682
#    3683     def set(self, item, value, check=False):
#
# D:\anaconda\lib\site-packages\pandas\core\internals.py in _rebuild_blknos_and_blklocs(self)
#    2886             rl = blk.mgr_locs
#    2887             new_blknos[rl.indexer] = blkno
# -> 2888             new_blklocs[rl.indexer] = np.arange(len(rl))
#    2889
#    2890         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
datatemp
# Out:
#       category_1_pvnum    index            user_id           category_1  \
# 0                    0  1079608      1523553916360  6693726201323251689
# 1                    1   231751      1523553916360  6693726201323251689
# 2                    2   686850      1523553916360  6693726201323251689
# 3                    0   165809      5742370312099  2871729383671301763
# 4                    1   325700      5742370312099  2871729383671301763
# 5                    0   281610     82470453442674  1909641874861640857
# 6                    0   990727     82470453442674  6670526099037031245
# 7                    0   413061     84493792031619  5685690139879409547
# 8                    1  1243515     84493792031619  5685690139879409547
# 9                    2  1091933     84493792031619  5685690139879409547
# 10                   3   748398     84493792031619  5685690139879409547
# 11                   0   199251     84493792031619  8841625760168847319
# 12                   1   800116     84493792031619  8841625760168847319
# 13                   0   638328    116523863131482  3348197449185791127
# 14                   1   399728    116523863131482  3348197449185791127
# 15                   2   271540    116523863131482  3348197449185791127
# 16                   0   719064    118869601891011  6670526099037031245
# 17                   1   709115    118869601891011  6670526099037031245
# 18                   2  1339948    118869601891011  6670526099037031245
# 19                   0   884719    139185858192371  3613783563199627217
# 20                   0   842653    229148490361325  1909641874861640857
# 21                   1   891285    229148490361325  1909641874861640857
# 22                   0   327154    229148490361325   768579787521575291
# 23                   1   724990    229148490361325   768579787521575291
# 24                   0   798274    253082266017401  8841625760168847319
# 25                   0   145706    260383207933749   768579787521575291
# 26                   0   502849    279923877301037  3613783563199627217
# 27                   0   948479    279923877301037  5685690139879409547
# 28                   0   427972    315906374839470  6693726201323251689
# 29                   0  1334786    318010387239957  5685690139879409547
# ...                ...      ...                ...                  ...
# 6333                 1   998297  45127903718619131  1909641874861640857
# 6334                 2   860406  45127903718619131  1909641874861640857
# 6335                 0   200972  45127903718619131  3613783563199627217
# 6336                 1   236722  45127903718619131  3613783563199627217
# 6337                 2  1338099  45127903718619131  3613783563199627217
# 6338                 3   548636  45127903718619131  3613783563199627217
# 6339                 4   835760  45127903718619131  3613783563199627217
# 6340                 5   698495  45127903718619131  3613783563199627217
# 6341                 6   834723  45127903718619131  3613783563199627217
