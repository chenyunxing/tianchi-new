# %%
#coding:utf-8
import pandas as pd
import time

from sklearn.metrics import log_loss
# instance_id 样本编号
# item_id 广告商品编号
# item_category_list 广告商品的的类目列表 分割; item_property_list_0 item_property_list_1 item_property_list_2
# item_property_list 广告商品的属性列表 分割 1 2 3
# item_brand_id 广告商品的品牌编号
# item_city_id 广告商品的城市编号
# item_price_level 广告商品的价格等级
# item_sales_level 广告商品的销量等级
# item_collected_level 广告商品被收藏次数的等级
# item_pv_level 广告商品被展示次数的等级
# user_id 用户的编号
# 'user_gender_id', 用户的预测性别编号
# 'user_age_level', 用户的预测年龄等级
# 'user_occupation_id', 用户的预测职业编号
# 'user_star_level' 用户的星级编号
# context_id 上下文信息的编号
#  context_timestamp 广告商品的展示时间
# context_page_id 广告商品的展示页面编号
# predict_category_property
def time2cov(time_):
    '''
    时间是根据天数推移，所以日期为脱敏，但是时间本身不脱敏
    :param time_: 
    :return: 
    '''
    return time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(time_))

def pre_process(data):
    '''
    :param data: 
    :return: 
    '''

    print('预处理')
#     print('item_category_list_ing')
#     for i in range(3):
#         data['category_%d'%(i)] = data['item_category_list'].apply(
#             lambda x:x.split(";")[i] if len(x.split(";")) > i else " "
#         )
#     del data['item_category_list']

#     print('item_property_list_ing')
#     for i in range(3):
#         data['property_%d'%(i)] = data['item_property_list'].apply(
#             lambda x:x.split(";")[i] if len(x.split(";")) > i else " "
#         )
#     del data['item_property_list']

    print('context_timestamp_ing')
    data['context_timestamp'] = data['context_timestamp'].apply(time2cov)

    print('time')
    data['context_timestamp_tmp'] = pd.to_datetime(data['context_timestamp'])
    data['week'] = data['context_timestamp_tmp'].dt.weekday
    data['hour'] = data['context_timestamp_tmp'].dt.hour
    data['minute'] = data['context_timestamp_tmp'].dt.minute
    data['halfhour'] = (data['hour']+1)*6+(data['minute']/10).astype('int')
    del data['context_timestamp_tmp']
    del data['minute']
    del data['week']


#     print('predict_category_property_ing_0')
#     for i in range(3):
#         data['predict_category_%d'%(i)] = data['predict_category_property'].apply(
#             lambda x:str(x.split(";")[i]).split(":")[0] if len(x.split(";")) > i else " "
#         )
#     for i in range(3):
#         temp = data[['user_occupation_id','property_%d'%(i),'instance_id']].groupby(['user_occupation_id','property_%d'%(i)]).aggregate('count')
#         temp1 = temp.reset_index()
#         temp2 = temp.groupby('user_occupation_id').sum().reset_index()
#         temp3 = pd.merge(temp1,temp2,on=['user_occupation_id'],how='left')
#         temp4 = temp3[['instance_id_x']].rename(columns=({'instance_id_x':'sum'}))/temp3[['instance_id_y']].rename(columns=({'instance_id_y':'sum'}))
#         temp3['property_%dpv'%(i)] = temp4
#         temp3.drop('instance_id_x', axis=1, inplace=True)
#         temp3.drop('instance_id_y', axis=1, inplace=True)
#         data = pd.merge(data,temp3,on=['user_occupation_id','property_%d'%(i)],how='left')
#     for i in range(1,3):
#         temp = data[['user_occupation_id','category_%d'%(i),'instance_id']].groupby(['user_occupation_id','category_%d'%(i)]).aggregate('count')
#         temp1 = temp.reset_index()
#         temp2 = temp.groupby('user_occupation_id').sum().reset_index()
#         temp3 = pd.merge(temp1,temp2,on=['user_occupation_id'],how='left')
#         temp4 = temp3[['instance_id_x']].rename(columns=({'instance_id_x':'sum'}))/temp3[['instance_id_y']].rename(columns=({'instance_id_y':'sum'}))
#         temp3['category_%dpv'%(i)] = temp4
#         temp3.drop('instance_id_x', axis=1, inplace=True)
#         temp3.drop('instance_id_y', axis=1, inplace=True)
#         data = pd.merge(data,temp3,on=['user_occupation_id','category_%d'%(i)],how='left')
#     for i in range(3):
#         temp = data[['user_gender_id','property_%d'%(i),'instance_id']].groupby(['user_gender_id','property_%d'%(i)]).aggregate('count')
#         temp1 = temp.reset_index()
#         temp2 = temp.groupby('user_gender_id').sum().reset_index()
#         temp3 = pd.merge(temp1,temp2,on=['user_gender_id'],how='left')
#         temp4 = temp3[['instance_id_x']].rename(columns=({'instance_id_x':'sum'}))/temp3[['instance_id_y']].rename(columns=({'instance_id_y':'sum'}))
#         temp3['property_%dpv'%(i)] = temp4
#         temp3.drop('instance_id_x', axis=1, inplace=True)
#         temp3.drop('instance_id_y', axis=1, inplace=True)
#         data = pd.merge(data,temp3,on=['user_gender_id','property_%d'%(i)],how='left')
#     for i in range(1,3):
#         temp = data[['user_gender_id','category_%d'%(i),'instance_id']].groupby(['user_gender_id','category_%d'%(i)]).aggregate('count')
#         temp1 = temp.reset_index()
#         temp2 = temp.groupby('user_gender_id').sum().reset_index()
#         temp3 = pd.merge(temp1,temp2,on=['user_gender_id'],how='left')
#         temp4 = temp3[['instance_id_x']].rename(columns=({'instance_id_x':'sum'}))/temp3[['instance_id_y']].rename(columns=({'instance_id_y':'sum'}))
#         temp3['category_%dpv'%(i)] = temp4
#         temp3.drop('instance_id_x', axis=1, inplace=True)
#         temp3.drop('instance_id_y', axis=1, inplace=True)
#         data = pd.merge(data,temp3,on=['user_gender_id','category_%d'%(i)],how='left')
#     temp = data[['user_age_level','item_price_level','instance_id']].groupby(['user_age_level','item_price_level']).aggregate('count')
#     temp1 = temp.reset_index()
#     temp2 = temp.groupby('user_age_level').sum().reset_index()
#     temp3 = pd.merge(temp1,temp2,on=['user_age_level'],how='left')
#     temp4 = temp3[['instance_id_x']].rename(columns=({'instance_id_x':'sum'}))/temp3[['instance_id_y']].rename(columns=({'instance_id_y':'sum'}))
#     temp3['age_pv'] = temp4
#     temp3.drop('instance_id_x', axis=1, inplace=True)
#     temp3.drop('instance_id_y', axis=1, inplace=True)
#     data = pd.merge(data,temp3,on=['user_age_level','user_age_level'],how='left')
#     del(temp3)
#     del(temp2)
#     del(temp1)
#     del(temp4)
#     del(temp)
#     print('predict_category_property_ing_1')
#     for i in range(3):
#         data['predict_property_%d'%(i)] = data['predict_category_property'].apply(
#             lambda x:str(x.split(";")[i]).split(":")[1] if len(x.split(";")) > i else " "
#         )
    
#         for j in range(3):
#             data['predict_property_%d_%d' % (i,j)] = data['predict_property_%d'%(i)].apply(
#                 lambda x: x.split(",")[j] if len(x.split(",")) > j else -1
#             )

    del data['predict_category_property']
    del data['item_category_list']
    del data['item_property_list']
    del data['item_city_id']
    del data['shop_score_service']
    del data['shop_score_description']
    del data['shop_review_positive_rate']
    del data['shop_score_delivery']
    return data

# %%
print('train')
train = pd.read_csv('train.csv',index_col=False)
dataa = pd.read_csv('train_all.csv',index_col=False) 
train = pd.merge(train,dataa,on=['instance_id'],how='left')
train = pre_process(train)
# Out:
# train
# 预处理
# context_timestamp_ing
# time

# %%
train.columns
# Out:
# Index(['instance_id', 'item_id', 'item_brand_id', 'item_price_level',
#        'item_sales_level', 'item_collected_level', 'item_pv_level', 'user_id',
#        'user_gender_id', 'user_age_level', 'user_occupation_id',
#        'user_star_level', 'context_id', 'context_timestamp', 'context_page_id',
#        'shop_id', 'shop_review_num_level', 'shop_star_level', 'is_trade',
#        'item_category_list_num', 'item_property_list_num', 'hour_num',
#        'item_click', 'shop_score_service_num', 'shop_score_description_num',
#        'shop_review_positive_rate_num', 'shop_score_delivery_num',
#        'user_click', 'hour', 'halfhour'],
#       dtype='object')

# %%
all_data = train.copy()


print('all_shape',train.shape)
print(train['context_timestamp'].max())
val = train[train['context_timestamp']>'2018-09-22 23:59:59']

# 空去 22 号

train = train[train['context_timestamp']<='2018-09-22 23:59:59']

train = train[train['context_timestamp']>'2018-09-19 23:59:59']
print(train.shape)
print(val.shape)
# Out:
# all_shape (478831, 30)
# 2018-09-24 23:59:47
# (208344, 30)
# (121179, 30)

# %%
print('test')
test_a = pd.read_csv('test.csv',index_col=False)
data2a = pd.read_csv('test_all.csv',index_col=False) 
test_a = pd.merge(test_a,data2a,on=['instance_id'],how='left')
test_a = pre_process(test_a)
# Out:
# test
# 预处理
# context_timestamp_ing
# time

# %%
# del train['shop_id']
# del val['shop_id']
# del test_a['shop_id']

# %%
# 这里是增加的内容
import datetime
def get_count_feat(all_data,data,long=3):
    end_time = data['context_timestamp'].min()
    begin_time = pd.to_datetime(end_time) - datetime.timedelta(days=long)
    all_data['context_timestamp'] = pd.to_datetime(all_data['context_timestamp'])
    all_data = all_data[
        (all_data['context_timestamp']<end_time)&(all_data['context_timestamp']>=begin_time)
                    ]
    print(end_time)
    print(begin_time)
    print(all_data['context_timestamp'].max()-all_data['context_timestamp'].min())
    item_count = all_data.groupby(['item_id'],as_index=False).size().reset_index()
    item_count.rename(columns={0:'item_count'},inplace=True)

    user_count = all_data.groupby(['user_id'], as_index=False).size().reset_index()
    user_count.rename(columns={0: 'user_count'}, inplace=True)
    return user_count,item_count

# %%
train_user_count,train_item_count = get_count_feat(all_data,train,2)

test_user_count,test_item_count = get_count_feat(all_data,test_a,2)

val_user_count,val_item_count = get_count_feat(all_data,val,2)

train = pd.merge(train,train_user_count,on=['user_id'],how='left')
train = pd.merge(train,train_item_count,on=['item_id'],how='left')
train = train.fillna(-1)
val = pd.merge(val,val_user_count,on=['user_id'],how='left')
val = pd.merge(val,val_item_count,on=['item_id'],how='left')
val = val.fillna(-1)
test_a = pd.merge(test_a,test_user_count,on=['user_id'],how='left')
test_a = pd.merge(test_a,test_item_count,on=['item_id'],how='left')
test_a = test_a.fillna(-1)
y_train = train.pop('is_trade')
train_index = train.pop('instance_id')

y_val = val.pop('is_trade')
val_index = val.pop('instance_id')
test_index = test_a.pop('instance_id')
# Out:
# 2018-09-20 00:00:01
# 2018-09-18 00:00:01
# 1 days 23:59:54
# 2018-09-25 00:00:02
# 2018-09-23 00:00:02
# 1 days 23:59:44
# 2018-09-23 00:00:03
# 2018-09-21 00:00:03
# 1 days 23:59:43

# %%
print(test_a.shape)
del train['context_timestamp']
del val['context_timestamp']
del test_a['context_timestamp']
del all_data
# Out:
# (18371, 30)

# %%
print('baseline ing ... ...')
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from scipy import sparse
from sklearn.linear_model import LogisticRegression
# print(test_a.columns)


enc = OneHotEncoder()
lb = LabelEncoder()
feat_set = list(test_a.columns)
for i,feat in enumerate(feat_set):
    tmp = lb.fit_transform((list(train[feat])+list(val[feat])+list(test_a[feat])))
    enc.fit(tmp.reshape(-1,1))
    x_train = enc.transform(lb.transform(train[feat]).reshape(-1, 1))
    x_test = enc.transform(lb.transform(test_a[feat]).reshape(-1, 1))
    x_val = enc.transform(lb.transform(val[feat]).reshape(-1, 1))
    if i == 0:
        X_train, X_test,X_val = x_train, x_test,x_val
    else:
        X_train, X_test,X_val = sparse.hstack((X_train, x_train)), sparse.hstack((X_test, x_test)),sparse.hstack((X_val, x_val))
X_train, X_test,X_val = sparse.hstack((X_train, x_train)), sparse.hstack((X_test, x_test)),sparse.hstack((X_val, x_val))
print("end")
# Out:
# baseline ing ... ...
# end

# %%
# LogisticRegression?

# %%
# lr.fit?

# %%
lr = LogisticRegression(penalty='l1',C=0.5)


lr.fit(X_train, y_train)
proba_val = lr.predict_proba(X_val)[:,1]
proba_sub = lr.predict_proba(X_test)[:,1]

# %%
print(log_loss(y_train,lr.predict_proba(X_train)[:,1]))
print(log_loss(y_val,proba_val))#0.0855354191184
# Out:
# 0.0864675592886
# 0.0831021782982

# %%
import lightgbm as lgb
gbm = lgb.LGBMRegressor(objective='binary',
                        num_leaves=50,
                        learning_rate=0.01,
                        n_estimators=2000,
                        colsample_bytree = 0.65,
                        subsample = 0.7,
                        reg_alpha = 2
                       )
gbm.fit(X_train, y_train,
        eval_set=[(X_val, y_val)],
        eval_metric='binary_logloss',
        early_stopping_rounds=150)
# Out:
# [1]	valid_0's binary_logloss: 0.683899
# Training until validation scores don't improve for 150 rounds.
# [2]	valid_0's binary_logloss: 0.674834
# [3]	valid_0's binary_logloss: 0.665945
# [4]	valid_0's binary_logloss: 0.65723
# [5]	valid_0's binary_logloss: 0.648684
# [6]	valid_0's binary_logloss: 0.640298
# [7]	valid_0's binary_logloss: 0.63207
# [8]	valid_0's binary_logloss: 0.623994
# [9]	valid_0's binary_logloss: 0.616076
# [10]	valid_0's binary_logloss: 0.608303
# [11]	valid_0's binary_logloss: 0.60067
# [12]	valid_0's binary_logloss: 0.593177
# [13]	valid_0's binary_logloss: 0.585813
# [14]	valid_0's binary_logloss: 0.578586
# [15]	valid_0's binary_logloss: 0.571487
# [16]	valid_0's binary_logloss: 0.564516
# [17]	valid_0's binary_logloss: 0.557671
# [18]	valid_0's binary_logloss: 0.550939
# [19]	valid_0's binary_logloss: 0.544328
# [20]	valid_0's binary_logloss: 0.537825
# [21]	valid_0's binary_logloss: 0.531439
# [22]	valid_0's binary_logloss: 0.525153
# [23]	valid_0's binary_logloss: 0.518983
# [24]	valid_0's binary_logloss: 0.512909
# [25]	valid_0's binary_logloss: 0.506934
# [26]	valid_0's binary_logloss: 0.501063
# [27]	valid_0's binary_logloss: 0.495288
# [28]	valid_0's binary_logloss: 0.489609
# [29]	valid_0's binary_logloss: 0.484021
# [30]	valid_0's binary_logloss: 0.478521
# [31]	valid_0's binary_logloss: 0.473112
# [32]	valid_0's binary_logloss: 0.467788
# [33]	valid_0's binary_logloss: 0.462546
# [34]	valid_0's binary_logloss: 0.45739
# [35]	valid_0's binary_logloss: 0.452314
# [36]	valid_0's binary_logloss: 0.447317
# [37]	valid_0's binary_logloss: 0.442403
# [38]	valid_0's binary_logloss: 0.437564
# [39]	valid_0's binary_logloss: 0.432796
# [40]	valid_0's binary_logloss: 0.428108
# [41]	valid_0's binary_logloss: 0.423486
# [42]	valid_0's binary_logloss: 0.418933
# [43]	valid_0's binary_logloss: 0.414458
# [44]	valid_0's binary_logloss: 0.410049
# [45]	valid_0's binary_logloss: 0.405701
# [46]	valid_0's binary_logloss: 0.401417
# [47]	valid_0's binary_logloss: 0.3972
# [48]	valid_0's binary_logloss: 0.393049
# [49]	valid_0's binary_logloss: 0.388957
# [50]	valid_0's binary_logloss: 0.384923
# [51]	valid_0's binary_logloss: 0.380948
# [52]	valid_0's binary_logloss: 0.377033
# [53]	valid_0's binary_logloss: 0.373169
# [54]	valid_0's binary_logloss: 0.369366
# [55]	valid_0's binary_logloss: 0.365617
# [56]	valid_0's binary_logloss: 0.361925
# [57]	valid_0's binary_logloss: 0.358286
# [58]	valid_0's binary_logloss: 0.354702
# [59]	valid_0's binary_logloss: 0.351163
# [60]	valid_0's binary_logloss: 0.347675
# [61]	valid_0's binary_logloss: 0.344243
# [62]	valid_0's binary_logloss: 0.340858
# [63]	valid_0's binary_logloss: 0.337517
# [64]	valid_0's binary_logloss: 0.334225
# [65]	valid_0's binary_logloss: 0.330978
# [66]	valid_0's binary_logloss: 0.327778
# [67]	valid_0's binary_logloss: 0.324622
# [68]	valid_0's binary_logloss: 0.321513
# [69]	valid_0's binary_logloss: 0.318443
# [70]	valid_0's binary_logloss: 0.315415
# [71]	valid_0's binary_logloss: 0.312424
# [72]	valid_0's binary_logloss: 0.309481
# [73]	valid_0's binary_logloss: 0.306581
# [74]	valid_0's binary_logloss: 0.303721
# [75]	valid_0's binary_logloss: 0.300898
# [76]	valid_0's binary_logloss: 0.298109
# [77]	valid_0's binary_logloss: 0.295362
# [78]	valid_0's binary_logloss: 0.29265
# [79]	valid_0's binary_logloss: 0.289973
# [80]	valid_0's binary_logloss: 0.287334
# [81]	valid_0's binary_logloss: 0.284736
# [82]	valid_0's binary_logloss: 0.282162
# [83]	valid_0's binary_logloss: 0.27963
# [84]	valid_0's binary_logloss: 0.277128
# [85]	valid_0's binary_logloss: 0.274664
# [86]	valid_0's binary_logloss: 0.272234
# [87]	valid_0's binary_logloss: 0.269831
# [88]	valid_0's binary_logloss: 0.267462
# [89]	valid_0's binary_logloss: 0.265127
# [90]	valid_0's binary_logloss: 0.262817
# [91]	valid_0's binary_logloss: 0.260543
# [92]	valid_0's binary_logloss: 0.258298
# [93]	valid_0's binary_logloss: 0.256084
# [94]	valid_0's binary_logloss: 0.253902
# [95]	valid_0's binary_logloss: 0.251744
# [96]	valid_0's binary_logloss: 0.249616
# [97]	valid_0's binary_logloss: 0.247514
# [98]	valid_0's binary_logloss: 0.245446
# [99]	valid_0's binary_logloss: 0.243397
# [100]	valid_0's binary_logloss: 0.241376
# [101]	valid_0's binary_logloss: 0.239381
# [102]	valid_0's binary_logloss: 0.237411
# [103]	valid_0's binary_logloss: 0.235467
# [104]	valid_0's binary_logloss: 0.233551
# [105]	valid_0's binary_logloss: 0.231658
# [106]	valid_0's binary_logloss: 0.229785
# [107]	valid_0's binary_logloss: 0.227937
# [108]	valid_0's binary_logloss: 0.226118
# [109]	valid_0's binary_logloss: 0.224318
# [110]	valid_0's binary_logloss: 0.222549
# [111]	valid_0's binary_logloss: 0.220798
# [112]	valid_0's binary_logloss: 0.219065
# [113]	valid_0's binary_logloss: 0.217355
# [114]	valid_0's binary_logloss: 0.215665
# [115]	valid_0's binary_logloss: 0.214004
# [116]	valid_0's binary_logloss: 0.212359
# [117]	valid_0's binary_logloss: 0.210735
# [118]	valid_0's binary_logloss: 0.209131
# [119]	valid_0's binary_logloss: 0.207545
# [120]	valid_0's binary_logloss: 0.205983
# [121]	valid_0's binary_logloss: 0.20444
# [122]	valid_0's binary_logloss: 0.202918
# [123]	valid_0's binary_logloss: 0.201413
# [124]	valid_0's binary_logloss: 0.199929
# [125]	valid_0's binary_logloss: 0.198457
# [126]	valid_0's binary_logloss: 0.197006
# [127]	valid_0's binary_logloss: 0.195579
# [128]	valid_0's binary_logloss: 0.194163
# [129]	valid_0's binary_logloss: 0.19277
# [130]	valid_0's binary_logloss: 0.191389
# [131]	valid_0's binary_logloss: 0.19003
# [132]	valid_0's binary_logloss: 0.18869
# [133]	valid_0's binary_logloss: 0.187361
# [134]	valid_0's binary_logloss: 0.186055
# [135]	valid_0's binary_logloss: 0.184765
# [136]	valid_0's binary_logloss: 0.183488
# [137]	valid_0's binary_logloss: 0.18223
# [138]	valid_0's binary_logloss: 0.180984
# [139]	valid_0's binary_logloss: 0.179758
# [140]	valid_0's binary_logloss: 0.178542
# [141]	valid_0's binary_logloss: 0.177343
# [142]	valid_0's binary_logloss: 0.176157
# [143]	valid_0's binary_logloss: 0.174989
# [144]	valid_0's binary_logloss: 0.173836
# [145]	valid_0's binary_logloss: 0.172697
# [146]	valid_0's binary_logloss: 0.171571
# [147]	valid_0's binary_logloss: 0.170461
# [148]	valid_0's binary_logloss: 0.16936
# [149]	valid_0's binary_logloss: 0.168273
# [150]	valid_0's binary_logloss: 0.167202
# [151]	valid_0's binary_logloss: 0.166145
# [152]	valid_0's binary_logloss: 0.165098
# [153]	valid_0's binary_logloss: 0.164062
# [154]	valid_0's binary_logloss: 0.16304
# [155]	valid_0's binary_logloss: 0.162031
# [156]	valid_0's binary_logloss: 0.161037
# [157]	valid_0's binary_logloss: 0.160051
# [158]	valid_0's binary_logloss: 0.15908
# [159]	valid_0's binary_logloss: 0.158123
# [160]	valid_0's binary_logloss: 0.157178
# [161]	valid_0's binary_logloss: 0.156243
# [162]	valid_0's binary_logloss: 0.155322
# [163]	valid_0's binary_logloss: 0.154405
# [164]	valid_0's binary_logloss: 0.153504
# [165]	valid_0's binary_logloss: 0.152615
# [166]	valid_0's binary_logloss: 0.151735
# [167]	valid_0's binary_logloss: 0.150865
# [168]	valid_0's binary_logloss: 0.150008
# [169]	valid_0's binary_logloss: 0.149162
# [170]	valid_0's binary_logloss: 0.148327
# [171]	valid_0's binary_logloss: 0.1475
# [172]	valid_0's binary_logloss: 0.146682
# [173]	valid_0's binary_logloss: 0.145878
# [174]	valid_0's binary_logloss: 0.145083
# [175]	valid_0's binary_logloss: 0.144299
# [176]	valid_0's binary_logloss: 0.143522
# [177]	valid_0's binary_logloss: 0.142754
# [178]	valid_0's binary_logloss: 0.141994
# [179]	valid_0's binary_logloss: 0.141245
# [180]	valid_0's binary_logloss: 0.140506
# [181]	valid_0's binary_logloss: 0.139774
# [182]	valid_0's binary_logloss: 0.139057
# [183]	valid_0's binary_logloss: 0.138344
# [184]	valid_0's binary_logloss: 0.137641
# [185]	valid_0's binary_logloss: 0.136942
# [186]	valid_0's binary_logloss: 0.136257
# [187]	valid_0's binary_logloss: 0.135581
# [188]	valid_0's binary_logloss: 0.134912
# [189]	valid_0's binary_logloss: 0.134248
# [190]	valid_0's binary_logloss: 0.133594
# [191]	valid_0's binary_logloss: 0.132946
# [192]	valid_0's binary_logloss: 0.132308
# [193]	valid_0's binary_logloss: 0.131678
# [194]	valid_0's binary_logloss: 0.131055
# [195]	valid_0's binary_logloss: 0.130443
# [196]	valid_0's binary_logloss: 0.129834
# [197]	valid_0's binary_logloss: 0.129238
# [198]	valid_0's binary_logloss: 0.128647
# [199]	valid_0's binary_logloss: 0.128066
# [200]	valid_0's binary_logloss: 0.127487
# [201]	valid_0's binary_logloss: 0.126918
# [202]	valid_0's binary_logloss: 0.126354
# [203]	valid_0's binary_logloss: 0.125799
# [204]	valid_0's binary_logloss: 0.12525
# [205]	valid_0's binary_logloss: 0.124709
# [206]	valid_0's binary_logloss: 0.124175
# [207]	valid_0's binary_logloss: 0.123646
# [208]	valid_0's binary_logloss: 0.123122
# [209]	valid_0's binary_logloss: 0.122604
# [210]	valid_0's binary_logloss: 0.122096
# [211]	valid_0's binary_logloss: 0.121595
# [212]	valid_0's binary_logloss: 0.121101
# [213]	valid_0's binary_logloss: 0.120613
# [214]	valid_0's binary_logloss: 0.120127
# [215]	valid_0's binary_logloss: 0.119651
# [216]	valid_0's binary_logloss: 0.119178
# [217]	valid_0's binary_logloss: 0.118709
# [218]	valid_0's binary_logloss: 0.118249
# [219]	valid_0's binary_logloss: 0.117796
# [220]	valid_0's binary_logloss: 0.117349
# [221]	valid_0's binary_logloss: 0.116905
# [222]	valid_0's binary_logloss: 0.116468
# [223]	valid_0's binary_logloss: 0.116037
# [224]	valid_0's binary_logloss: 0.11561
# [225]	valid_0's binary_logloss: 0.115189
# [226]	valid_0's binary_logloss: 0.114774
# [227]	valid_0's binary_logloss: 0.114365
# [228]	valid_0's binary_logloss: 0.11396
# [229]	valid_0's binary_logloss: 0.113555
# [230]	valid_0's binary_logloss: 0.11316
# [231]	valid_0's binary_logloss: 0.112768
# [232]	valid_0's binary_logloss: 0.112386
# [233]	valid_0's binary_logloss: 0.112004
# [234]	valid_0's binary_logloss: 0.111628
# [235]	valid_0's binary_logloss: 0.111255
# [236]	valid_0's binary_logloss: 0.110887
# [237]	valid_0's binary_logloss: 0.110522
# [238]	valid_0's binary_logloss: 0.110163
# [239]	valid_0's binary_logloss: 0.10981
# [240]	valid_0's binary_logloss: 0.109461
# [241]	valid_0's binary_logloss: 0.109117
# [242]	valid_0's binary_logloss: 0.108778
# [243]	valid_0's binary_logloss: 0.108439
# [244]	valid_0's binary_logloss: 0.108111
# [245]	valid_0's binary_logloss: 0.107784
# [246]	valid_0's binary_logloss: 0.10746
# [247]	valid_0's binary_logloss: 0.107141
# [248]	valid_0's binary_logloss: 0.106825
# [249]	valid_0's binary_logloss: 0.106516
# [250]	valid_0's binary_logloss: 0.106209
# [251]	valid_0's binary_logloss: 0.105906
# [252]	valid_0's binary_logloss: 0.105606
# [253]	valid_0's binary_logloss: 0.10531
# [254]	valid_0's binary_logloss: 0.105016
# [255]	valid_0's binary_logloss: 0.104728
# [256]	valid_0's binary_logloss: 0.104443
# [257]	valid_0's binary_logloss: 0.104159
# [258]	valid_0's binary_logloss: 0.103883
# [259]	valid_0's binary_logloss: 0.103609
# [260]	valid_0's binary_logloss: 0.103337
# [261]	valid_0's binary_logloss: 0.103068
# [262]	valid_0's binary_logloss: 0.102802
# [263]	valid_0's binary_logloss: 0.102543
# [264]	valid_0's binary_logloss: 0.102286
# [265]	valid_0's binary_logloss: 0.102033
# [266]	valid_0's binary_logloss: 0.101781
# [267]	valid_0's binary_logloss: 0.101535
# [268]	valid_0's binary_logloss: 0.101291
# [269]	valid_0's binary_logloss: 0.101051
# [270]	valid_0's binary_logloss: 0.100812
# [271]	valid_0's binary_logloss: 0.100578
# [272]	valid_0's binary_logloss: 0.100346
# [273]	valid_0's binary_logloss: 0.100117
# [274]	valid_0's binary_logloss: 0.0998907
# [275]	valid_0's binary_logloss: 0.0996685
# [276]	valid_0's binary_logloss: 0.0994502
# [277]	valid_0's binary_logloss: 0.0992346
# [278]	valid_0's binary_logloss: 0.0990206
# [279]	valid_0's binary_logloss: 0.0988083
# [280]	valid_0's binary_logloss: 0.0986012
# [281]	valid_0's binary_logloss: 0.0983956
# [282]	valid_0's binary_logloss: 0.0981924
# [283]	valid_0's binary_logloss: 0.0979936
# [284]	valid_0's binary_logloss: 0.097798
# [285]	valid_0's binary_logloss: 0.0975996
# [286]	valid_0's binary_logloss: 0.0974082
# [287]	valid_0's binary_logloss: 0.0972174
# [288]	valid_0's binary_logloss: 0.0970312
# [289]	valid_0's binary_logloss: 0.0968463
# [290]	valid_0's binary_logloss: 0.0966623
# [291]	valid_0's binary_logloss: 0.0964821
# [292]	valid_0's binary_logloss: 0.0963058
# [293]	valid_0's binary_logloss: 0.0961314
# [294]	valid_0's binary_logloss: 0.0959569
# [295]	valid_0's binary_logloss: 0.0957871
# [296]	valid_0's binary_logloss: 0.0956159
# [297]	valid_0's binary_logloss: 0.09545
# [298]	valid_0's binary_logloss: 0.0952857
# [299]	valid_0's binary_logloss: 0.0951221
# [300]	valid_0's binary_logloss: 0.094963
# [301]	valid_0's binary_logloss: 0.0948042
# [302]	valid_0's binary_logloss: 0.0946466
# [303]	valid_0's binary_logloss: 0.094492
# [304]	valid_0's binary_logloss: 0.0943395
# [305]	valid_0's binary_logloss: 0.0941876
# [306]	valid_0's binary_logloss: 0.0940391
# [307]	valid_0's binary_logloss: 0.0938921
# [308]	valid_0's binary_logloss: 0.0937462
# [309]	valid_0's binary_logloss: 0.0936067
# [310]	valid_0's binary_logloss: 0.093467
# [311]	valid_0's binary_logloss: 0.0933279
# [312]	valid_0's binary_logloss: 0.0931954
# [313]	valid_0's binary_logloss: 0.0930614
# [314]	valid_0's binary_logloss: 0.0929307
# [315]	valid_0's binary_logloss: 0.0927996
# [316]	valid_0's binary_logloss: 0.0926703
# [317]	valid_0's binary_logloss: 0.0925427
# [318]	valid_0's binary_logloss: 0.0924153
# [319]	valid_0's binary_logloss: 0.0922885
# [320]	valid_0's binary_logloss: 0.092168
# [321]	valid_0's binary_logloss: 0.0920459
# [322]	valid_0's binary_logloss: 0.0919264
# [323]	valid_0's binary_logloss: 0.0918085
# [324]	valid_0's binary_logloss: 0.0916906
# [325]	valid_0's binary_logloss: 0.0915763
# [326]	valid_0's binary_logloss: 0.0914634
# [327]	valid_0's binary_logloss: 0.09135
# [328]	valid_0's binary_logloss: 0.0912372
# [329]	valid_0's binary_logloss: 0.0911292
# [330]	valid_0's binary_logloss: 0.0910208
# [331]	valid_0's binary_logloss: 0.0909163
# [332]	valid_0's binary_logloss: 0.0908121
# [333]	valid_0's binary_logloss: 0.0907098
# [334]	valid_0's binary_logloss: 0.0906079
# [335]	valid_0's binary_logloss: 0.0905073
# [336]	valid_0's binary_logloss: 0.0904094
# [337]	valid_0's binary_logloss: 0.090314
# [338]	valid_0's binary_logloss: 0.0902182
# [339]	valid_0's binary_logloss: 0.0901273
# [340]	valid_0's binary_logloss: 0.0900346
# [341]	valid_0's binary_logloss: 0.0899443
# [342]	valid_0's binary_logloss: 0.0898547
# [343]	valid_0's binary_logloss: 0.0897652
# [344]	valid_0's binary_logloss: 0.089677
# [345]	valid_0's binary_logloss: 0.0895888
# [346]	valid_0's binary_logloss: 0.089502
# [347]	valid_0's binary_logloss: 0.0894182
# [348]	valid_0's binary_logloss: 0.0893337
# [349]	valid_0's binary_logloss: 0.0892525
# [350]	valid_0's binary_logloss: 0.0891704
# [351]	valid_0's binary_logloss: 0.0890926
# [352]	valid_0's binary_logloss: 0.0890137
# [353]	valid_0's binary_logloss: 0.0889335
# [354]	valid_0's binary_logloss: 0.0888566
# [355]	valid_0's binary_logloss: 0.0887789
# [356]	valid_0's binary_logloss: 0.0887045
# [357]	valid_0's binary_logloss: 0.0886313
# [358]	valid_0's binary_logloss: 0.0885589
# [359]	valid_0's binary_logloss: 0.0884871
# [360]	valid_0's binary_logloss: 0.088416
# [361]	valid_0's binary_logloss: 0.0883443
# [362]	valid_0's binary_logloss: 0.0882746
# [363]	valid_0's binary_logloss: 0.088206
# [364]	valid_0's binary_logloss: 0.0881404
# [365]	valid_0's binary_logloss: 0.0880751
# [366]	valid_0's binary_logloss: 0.088008
# [367]	valid_0's binary_logloss: 0.087945
# [368]	valid_0's binary_logloss: 0.0878827
# [369]	valid_0's binary_logloss: 0.0878211
# [370]	valid_0's binary_logloss: 0.0877592
# [371]	valid_0's binary_logloss: 0.0876994
# [372]	valid_0's binary_logloss: 0.0876404
# [373]	valid_0's binary_logloss: 0.0875811
# [374]	valid_0's binary_logloss: 0.0875249
# [375]	valid_0's binary_logloss: 0.087467
# [376]	valid_0's binary_logloss: 0.0874082
# [377]	valid_0's binary_logloss: 0.0873506
# [378]	valid_0's binary_logloss: 0.0872943
# [379]	valid_0's binary_logloss: 0.0872368
# [380]	valid_0's binary_logloss: 0.0871796
# [381]	valid_0's binary_logloss: 0.087127
# [382]	valid_0's binary_logloss: 0.0870774
# [383]	valid_0's binary_logloss: 0.0870262
# [384]	valid_0's binary_logloss: 0.0869742
# [385]	valid_0's binary_logloss: 0.086926
# [386]	valid_0's binary_logloss: 0.0868791
# [387]	valid_0's binary_logloss: 0.0868302
# [388]	valid_0's binary_logloss: 0.0867826
# [389]	valid_0's binary_logloss: 0.0867354
# [390]	valid_0's binary_logloss: 0.0866889
# [391]	valid_0's binary_logloss: 0.0866408
# [392]	valid_0's binary_logloss: 0.0865938
# [393]	valid_0's binary_logloss: 0.0865496
# [394]	valid_0's binary_logloss: 0.0865042
# [395]	valid_0's binary_logloss: 0.0864617
# [396]	valid_0's binary_logloss: 0.0864186
# [397]	valid_0's binary_logloss: 0.0863755
# [398]	valid_0's binary_logloss: 0.0863324
# [399]	valid_0's binary_logloss: 0.0862905
# [400]	valid_0's binary_logloss: 0.0862439
# [401]	valid_0's binary_logloss: 0.0862045
# [402]	valid_0's binary_logloss: 0.0861643
# [403]	valid_0's binary_logloss: 0.0861251
# [404]	valid_0's binary_logloss: 0.0860872
# [405]	valid_0's binary_logloss: 0.0860498
# [406]	valid_0's binary_logloss: 0.0860132
# [407]	valid_0's binary_logloss: 0.0859772
# [408]	valid_0's binary_logloss: 0.0859409
# [409]	valid_0's binary_logloss: 0.0859048
# [410]	valid_0's binary_logloss: 0.085867
# [411]	valid_0's binary_logloss: 0.0858302
# [412]	valid_0's binary_logloss: 0.0857941
# [413]	valid_0's binary_logloss: 0.0857612
# [414]	valid_0's binary_logloss: 0.085726
# [415]	valid_0's binary_logloss: 0.0856922
# [416]	valid_0's binary_logloss: 0.0856604
# [417]	valid_0's binary_logloss: 0.0856277
# [418]	valid_0's binary_logloss: 0.0855965
# [419]	valid_0's binary_logloss: 0.085566
# [420]	valid_0's binary_logloss: 0.0855363
# [421]	valid_0's binary_logloss: 0.085503
# [422]	valid_0's binary_logloss: 0.0854733
# [423]	valid_0's binary_logloss: 0.0854434
# [424]	valid_0's binary_logloss: 0.0854142
# [425]	valid_0's binary_logloss: 0.0853838
# [426]	valid_0's binary_logloss: 0.0853531
# [427]	valid_0's binary_logloss: 0.085323
# [428]	valid_0's binary_logloss: 0.0852959
# [429]	valid_0's binary_logloss: 0.0852691
# [430]	valid_0's binary_logloss: 0.085241
# [431]	valid_0's binary_logloss: 0.0852149
# [432]	valid_0's binary_logloss: 0.0851865
# [433]	valid_0's binary_logloss: 0.0851587
# [434]	valid_0's binary_logloss: 0.0851335
# [435]	valid_0's binary_logloss: 0.0851074
# [436]	valid_0's binary_logloss: 0.0850808
# [437]	valid_0's binary_logloss: 0.085057
# [438]	valid_0's binary_logloss: 0.0850315
# [439]	valid_0's binary_logloss: 0.0850083
# [440]	valid_0's binary_logloss: 0.0849836
# [441]	valid_0's binary_logloss: 0.0849598
# [442]	valid_0's binary_logloss: 0.0849394
# [443]	valid_0's binary_logloss: 0.0849166
# [444]	valid_0's binary_logloss: 0.0848936
# [445]	valid_0's binary_logloss: 0.0848702
# [446]	valid_0's binary_logloss: 0.084848
# [447]	valid_0's binary_logloss: 0.0848277
# [448]	valid_0's binary_logloss: 0.0848068
# [449]	valid_0's binary_logloss: 0.0847858
# [450]	valid_0's binary_logloss: 0.0847656
# [451]	valid_0's binary_logloss: 0.084745
# [452]	valid_0's binary_logloss: 0.0847253
# [453]	valid_0's binary_logloss: 0.0847038
# [454]	valid_0's binary_logloss: 0.0846848
# [455]	valid_0's binary_logloss: 0.0846638
# [456]	valid_0's binary_logloss: 0.0846432
# [457]	valid_0's binary_logloss: 0.0846242
# [458]	valid_0's binary_logloss: 0.0846048
# [459]	valid_0's binary_logloss: 0.0845838
# [460]	valid_0's binary_logloss: 0.0845648
# [461]	valid_0's binary_logloss: 0.0845457
# [462]	valid_0's binary_logloss: 0.0845285
# [463]	valid_0's binary_logloss: 0.0845097
# [464]	valid_0's binary_logloss: 0.0844922
# [465]	valid_0's binary_logloss: 0.0844734
# [466]	valid_0's binary_logloss: 0.0844565
# [467]	valid_0's binary_logloss: 0.0844401
# [468]	valid_0's binary_logloss: 0.0844209
# [469]	valid_0's binary_logloss: 0.0844063
# [470]	valid_0's binary_logloss: 0.0843923
# [471]	valid_0's binary_logloss: 0.0843759
# [472]	valid_0's binary_logloss: 0.0843605
# [473]	valid_0's binary_logloss: 0.0843438
# [474]	valid_0's binary_logloss: 0.0843277
# [475]	valid_0's binary_logloss: 0.084312
# [476]	valid_0's binary_logloss: 0.084296
# [477]	valid_0's binary_logloss: 0.084278
# [478]	valid_0's binary_logloss: 0.0842607
# [479]	valid_0's binary_logloss: 0.0842454
# [480]	valid_0's binary_logloss: 0.0842306
# [481]	valid_0's binary_logloss: 0.0842157
# [482]	valid_0's binary_logloss: 0.0842027
# [483]	valid_0's binary_logloss: 0.0841908
# [484]	valid_0's binary_logloss: 0.0841789
# [485]	valid_0's binary_logloss: 0.0841643
# [486]	valid_0's binary_logloss: 0.0841531
# [487]	valid_0's binary_logloss: 0.0841407
# [488]	valid_0's binary_logloss: 0.0841273
# [489]	valid_0's binary_logloss: 0.0841134
# [490]	valid_0's binary_logloss: 0.0841022
# [491]	valid_0's binary_logloss: 0.0840901
# [492]	valid_0's binary_logloss: 0.0840784
# [493]	valid_0's binary_logloss: 0.0840656
# [494]	valid_0's binary_logloss: 0.0840543
# [495]	valid_0's binary_logloss: 0.0840414
# [496]	valid_0's binary_logloss: 0.08403
# [497]	valid_0's binary_logloss: 0.0840177
# [498]	valid_0's binary_logloss: 0.0840067
# [499]	valid_0's binary_logloss: 0.0839971
# [500]	valid_0's binary_logloss: 0.0839865
# [501]	valid_0's binary_logloss: 0.0839752
# [502]	valid_0's binary_logloss: 0.0839635
# [503]	valid_0's binary_logloss: 0.0839541
# [504]	valid_0's binary_logloss: 0.0839434
# [505]	valid_0's binary_logloss: 0.0839317
# [506]	valid_0's binary_logloss: 0.0839231
# [507]	valid_0's binary_logloss: 0.0839126
# [508]	valid_0's binary_logloss: 0.0839041
# [509]	valid_0's binary_logloss: 0.0838951
# [510]	valid_0's binary_logloss: 0.0838834
# [511]	valid_0's binary_logloss: 0.0838734
# [512]	valid_0's binary_logloss: 0.0838634
# [513]	valid_0's binary_logloss: 0.0838525
# [514]	valid_0's binary_logloss: 0.0838414
# [515]	valid_0's binary_logloss: 0.0838299
# [516]	valid_0's binary_logloss: 0.0838213
# [517]	valid_0's binary_logloss: 0.0838123
# [518]	valid_0's binary_logloss: 0.0838031
# [519]	valid_0's binary_logloss: 0.0837951
# [520]	valid_0's binary_logloss: 0.0837879
# [521]	valid_0's binary_logloss: 0.0837783
# [522]	valid_0's binary_logloss: 0.08377
# [523]	valid_0's binary_logloss: 0.0837607
# [524]	valid_0's binary_logloss: 0.0837529
# [525]	valid_0's binary_logloss: 0.0837437
# [526]	valid_0's binary_logloss: 0.0837353
# [527]	valid_0's binary_logloss: 0.0837275
# [528]	valid_0's binary_logloss: 0.0837192
# [529]	valid_0's binary_logloss: 0.0837116
# [530]	valid_0's binary_logloss: 0.0837022
# [531]	valid_0's binary_logloss: 0.0836951
# [532]	valid_0's binary_logloss: 0.0836884
# [533]	valid_0's binary_logloss: 0.0836797
# [534]	valid_0's binary_logloss: 0.0836731
# [535]	valid_0's binary_logloss: 0.0836655
# [536]	valid_0's binary_logloss: 0.0836571
# [537]	valid_0's binary_logloss: 0.0836505
# [538]	valid_0's binary_logloss: 0.0836431
# [539]	valid_0's binary_logloss: 0.0836365
# [540]	valid_0's binary_logloss: 0.0836287
# [541]	valid_0's binary_logloss: 0.083622
# [542]	valid_0's binary_logloss: 0.0836149
# [543]	valid_0's binary_logloss: 0.0836071
# [544]	valid_0's binary_logloss: 0.0836001
# [545]	valid_0's binary_logloss: 0.0835957
# [546]	valid_0's binary_logloss: 0.0835901
# [547]	valid_0's binary_logloss: 0.0835841
# [548]	valid_0's binary_logloss: 0.0835795
# [549]	valid_0's binary_logloss: 0.083572
# [550]	valid_0's binary_logloss: 0.0835663
# [551]	valid_0's binary_logloss: 0.0835622
# [552]	valid_0's binary_logloss: 0.083555
# [553]	valid_0's binary_logloss: 0.0835494
# [554]	valid_0's binary_logloss: 0.0835435
# [555]	valid_0's binary_logloss: 0.0835344
# [556]	valid_0's binary_logloss: 0.0835279
# [557]	valid_0's binary_logloss: 0.0835198
# [558]	valid_0's binary_logloss: 0.0835134
# [559]	valid_0's binary_logloss: 0.0835075
# [560]	valid_0's binary_logloss: 0.0835036
# [561]	valid_0's binary_logloss: 0.0834993
# [562]	valid_0's binary_logloss: 0.0834913
# [563]	valid_0's binary_logloss: 0.0834857
# [564]	valid_0's binary_logloss: 0.0834803
# [565]	valid_0's binary_logloss: 0.0834757
# [566]	valid_0's binary_logloss: 0.08347
# [567]	valid_0's binary_logloss: 0.0834644
# [568]	valid_0's binary_logloss: 0.0834587
# [569]	valid_0's binary_logloss: 0.0834547
# [570]	valid_0's binary_logloss: 0.0834487
# [571]	valid_0's binary_logloss: 0.0834438
# [572]	valid_0's binary_logloss: 0.0834388
# [573]	valid_0's binary_logloss: 0.0834344
# [574]	valid_0's binary_logloss: 0.0834322
# [575]	valid_0's binary_logloss: 0.0834287
# [576]	valid_0's binary_logloss: 0.083424
# [577]	valid_0's binary_logloss: 0.0834185
# [578]	valid_0's binary_logloss: 0.0834129
# [579]	valid_0's binary_logloss: 0.0834075
# [580]	valid_0's binary_logloss: 0.0834043
# [581]	valid_0's binary_logloss: 0.0833983
# [582]	valid_0's binary_logloss: 0.0833942
# [583]	valid_0's binary_logloss: 0.0833915
# [584]	valid_0's binary_logloss: 0.0833874
# [585]	valid_0's binary_logloss: 0.0833824
# [586]	valid_0's binary_logloss: 0.0833772
# [587]	valid_0's binary_logloss: 0.0833735
# [588]	valid_0's binary_logloss: 0.0833711
# [589]	valid_0's binary_logloss: 0.0833668
# [590]	valid_0's binary_logloss: 0.0833644
# [591]	valid_0's binary_logloss: 0.0833599
# [592]	valid_0's binary_logloss: 0.083356
# [593]	valid_0's binary_logloss: 0.083353
# [594]	valid_0's binary_logloss: 0.0833478
# [595]	valid_0's binary_logloss: 0.0833447
# [596]	valid_0's binary_logloss: 0.0833418
# [597]	valid_0's binary_logloss: 0.0833364
# [598]	valid_0's binary_logloss: 0.083334
# [599]	valid_0's binary_logloss: 0.0833301
# [600]	valid_0's binary_logloss: 0.0833279
# [601]	valid_0's binary_logloss: 0.0833239
# [602]	valid_0's binary_logloss: 0.0833187
# [603]	valid_0's binary_logloss: 0.0833161
# [604]	valid_0's binary_logloss: 0.0833098
# [605]	valid_0's binary_logloss: 0.083306
# [606]	valid_0's binary_logloss: 0.0833021
# [607]	valid_0's binary_logloss: 0.0832963
# [608]	valid_0's binary_logloss: 0.0832911
# [609]	valid_0's binary_logloss: 0.0832865
# [610]	valid_0's binary_logloss: 0.0832844
# [611]	valid_0's binary_logloss: 0.08328
# [612]	valid_0's binary_logloss: 0.083276
# [613]	valid_0's binary_logloss: 0.0832721
# [614]	valid_0's binary_logloss: 0.0832671
# [615]	valid_0's binary_logloss: 0.0832644
# [616]	valid_0's binary_logloss: 0.0832628
# [617]	valid_0's binary_logloss: 0.0832612
# [618]	valid_0's binary_logloss: 0.0832581
# [619]	valid_0's binary_logloss: 0.0832553
# [620]	valid_0's binary_logloss: 0.083251
# [621]	valid_0's binary_logloss: 0.0832478
# [622]	valid_0's binary_logloss: 0.0832435
# [623]	valid_0's binary_logloss: 0.0832405
# [624]	valid_0's binary_logloss: 0.0832353
# [625]	valid_0's binary_logloss: 0.0832317
# [626]	valid_0's binary_logloss: 0.0832293
# [627]	valid_0's binary_logloss: 0.0832247
# [628]	valid_0's binary_logloss: 0.0832221
# [629]	valid_0's binary_logloss: 0.0832192
# [630]	valid_0's binary_logloss: 0.0832159
# [631]	valid_0's binary_logloss: 0.0832118
# [632]	valid_0's binary_logloss: 0.0832092
# [633]	valid_0's binary_logloss: 0.0832049
# [634]	valid_0's binary_logloss: 0.0832013
# [635]	valid_0's binary_logloss: 0.0831988
# [636]	valid_0's binary_logloss: 0.0831941
# [637]	valid_0's binary_logloss: 0.0831909
# [638]	valid_0's binary_logloss: 0.0831879
# [639]	valid_0's binary_logloss: 0.0831842
# [640]	valid_0's binary_logloss: 0.0831818
# [641]	valid_0's binary_logloss: 0.0831788
# [642]	valid_0's binary_logloss: 0.0831774
# [643]	valid_0's binary_logloss: 0.0831731
# [644]	valid_0's binary_logloss: 0.0831711
# [645]	valid_0's binary_logloss: 0.0831697
# [646]	valid_0's binary_logloss: 0.0831678
# [647]	valid_0's binary_logloss: 0.0831667
# [648]	valid_0's binary_logloss: 0.083164
# [649]	valid_0's binary_logloss: 0.0831629
# [650]	valid_0's binary_logloss: 0.083159
# [651]	valid_0's binary_logloss: 0.0831581
# [652]	valid_0's binary_logloss: 0.0831558
# [653]	valid_0's binary_logloss: 0.0831538
# [654]	valid_0's binary_logloss: 0.0831521
# [655]	valid_0's binary_logloss: 0.0831503
# [656]	valid_0's binary_logloss: 0.0831472
# [657]	valid_0's binary_logloss: 0.0831434
# [658]	valid_0's binary_logloss: 0.0831398
# [659]	valid_0's binary_logloss: 0.0831382
# [660]	valid_0's binary_logloss: 0.0831342
# [661]	valid_0's binary_logloss: 0.0831325
# [662]	valid_0's binary_logloss: 0.0831309
# [663]	valid_0's binary_logloss: 0.0831292
# [664]	valid_0's binary_logloss: 0.0831274
# [665]	valid_0's binary_logloss: 0.0831255
# [666]	valid_0's binary_logloss: 0.0831229
# [667]	valid_0's binary_logloss: 0.0831194
# [668]	valid_0's binary_logloss: 0.0831175
# [669]	valid_0's binary_logloss: 0.0831139
# [670]	valid_0's binary_logloss: 0.0831129
# [671]	valid_0's binary_logloss: 0.0831109
# [672]	valid_0's binary_logloss: 0.0831103
# [673]	valid_0's binary_logloss: 0.0831084
# [674]	valid_0's binary_logloss: 0.0831073
# [675]	valid_0's binary_logloss: 0.0831057
# [676]	valid_0's binary_logloss: 0.0831033
# [677]	valid_0's binary_logloss: 0.0831004
# [678]	valid_0's binary_logloss: 0.0830993
# [679]	valid_0's binary_logloss: 0.0830966
# [680]	valid_0's binary_logloss: 0.0830947
# [681]	valid_0's binary_logloss: 0.0830922
# [682]	valid_0's binary_logloss: 0.0830925
# [683]	valid_0's binary_logloss: 0.0830914
# [684]	valid_0's binary_logloss: 0.0830869
# [685]	valid_0's binary_logloss: 0.0830849
# [686]	valid_0's binary_logloss: 0.0830828
# [687]	valid_0's binary_logloss: 0.0830818
# [688]	valid_0's binary_logloss: 0.0830791
# [689]	valid_0's binary_logloss: 0.0830781
# [690]	valid_0's binary_logloss: 0.0830764
# [691]	valid_0's binary_logloss: 0.083074
# [692]	valid_0's binary_logloss: 0.0830735
# [693]	valid_0's binary_logloss: 0.083071
# [694]	valid_0's binary_logloss: 0.0830694
# [695]	valid_0's binary_logloss: 0.0830672
# [696]	valid_0's binary_logloss: 0.0830649
# [697]	valid_0's binary_logloss: 0.083063
# [698]	valid_0's binary_logloss: 0.0830623
# [699]	valid_0's binary_logloss: 0.0830614
# [700]	valid_0's binary_logloss: 0.0830608
# [701]	valid_0's binary_logloss: 0.08306
# [702]	valid_0's binary_logloss: 0.0830596
# [703]	valid_0's binary_logloss: 0.0830582
# [704]	valid_0's binary_logloss: 0.0830572
# [705]	valid_0's binary_logloss: 0.0830561
# [706]	valid_0's binary_logloss: 0.0830554
# [707]	valid_0's binary_logloss: 0.0830542
# [708]	valid_0's binary_logloss: 0.0830534
# [709]	valid_0's binary_logloss: 0.08305
# [710]	valid_0's binary_logloss: 0.0830481
# [711]	valid_0's binary_logloss: 0.0830465
# [712]	valid_0's binary_logloss: 0.0830438
# [713]	valid_0's binary_logloss: 0.0830422
# [714]	valid_0's binary_logloss: 0.0830396
# [715]	valid_0's binary_logloss: 0.0830365
# [716]	valid_0's binary_logloss: 0.0830359
# [717]	valid_0's binary_logloss: 0.0830357
# [718]	valid_0's binary_logloss: 0.0830358
# [719]	valid_0's binary_logloss: 0.0830351
# [720]	valid_0's binary_logloss: 0.0830336
# [721]	valid_0's binary_logloss: 0.0830324
# [722]	valid_0's binary_logloss: 0.0830317
# [723]	valid_0's binary_logloss: 0.0830296
# [724]	valid_0's binary_logloss: 0.0830301
# [725]	valid_0's binary_logloss: 0.0830291
# [726]	valid_0's binary_logloss: 0.0830255
# [727]	valid_0's binary_logloss: 0.0830235
# [728]	valid_0's binary_logloss: 0.0830223
# [729]	valid_0's binary_logloss: 0.0830215
# [730]	valid_0's binary_logloss: 0.0830194
# [731]	valid_0's binary_logloss: 0.083018
# [732]	valid_0's binary_logloss: 0.083017
# [733]	valid_0's binary_logloss: 0.0830168
# [734]	valid_0's binary_logloss: 0.0830155
# [735]	valid_0's binary_logloss: 0.0830142
# [736]	valid_0's binary_logloss: 0.0830127
# [737]	valid_0's binary_logloss: 0.0830121
# [738]	valid_0's binary_logloss: 0.0830112
# [739]	valid_0's binary_logloss: 0.0830093
# [740]	valid_0's binary_logloss: 0.0830088
# [741]	valid_0's binary_logloss: 0.0830089
# [742]	valid_0's binary_logloss: 0.0830082
# [743]	valid_0's binary_logloss: 0.0830092
# [744]	valid_0's binary_logloss: 0.0830096
# [745]	valid_0's binary_logloss: 0.0830082
# [746]	valid_0's binary_logloss: 0.0830078
# [747]	valid_0's binary_logloss: 0.0830062
# [748]	valid_0's binary_logloss: 0.0830057
# [749]	valid_0's binary_logloss: 0.0830048
# [750]	valid_0's binary_logloss: 0.0830023
# [751]	valid_0's binary_logloss: 0.0830013
# [752]	valid_0's binary_logloss: 0.0829994
# [753]	valid_0's binary_logloss: 0.0829989
# [754]	valid_0's binary_logloss: 0.0829966
# [755]	valid_0's binary_logloss: 0.0829956
# [756]	valid_0's binary_logloss: 0.0829946
# [757]	valid_0's binary_logloss: 0.0829938
# [758]	valid_0's binary_logloss: 0.0829939
# [759]	valid_0's binary_logloss: 0.0829928
# [760]	valid_0's binary_logloss: 0.082992
# [761]	valid_0's binary_logloss: 0.0829917
# [762]	valid_0's binary_logloss: 0.0829899
# [763]	valid_0's binary_logloss: 0.0829898
# [764]	valid_0's binary_logloss: 0.0829891
# [765]	valid_0's binary_logloss: 0.0829873
# [766]	valid_0's binary_logloss: 0.0829868
# [767]	valid_0's binary_logloss: 0.0829868
# [768]	valid_0's binary_logloss: 0.0829846
# [769]	valid_0's binary_logloss: 0.0829837
# [770]	valid_0's binary_logloss: 0.0829838
# [771]	valid_0's binary_logloss: 0.0829826
# [772]	valid_0's binary_logloss: 0.0829817
# [773]	valid_0's binary_logloss: 0.0829813
# [774]	valid_0's binary_logloss: 0.0829798
# [775]	valid_0's binary_logloss: 0.0829781
# [776]	valid_0's binary_logloss: 0.0829786
# [777]	valid_0's binary_logloss: 0.082977
# [778]	valid_0's binary_logloss: 0.0829751
# [779]	valid_0's binary_logloss: 0.0829746
# [780]	valid_0's binary_logloss: 0.0829756
# [781]	valid_0's binary_logloss: 0.0829758
# [782]	valid_0's binary_logloss: 0.0829746
# [783]	valid_0's binary_logloss: 0.0829752
# [784]	valid_0's binary_logloss: 0.0829752
# [785]	valid_0's binary_logloss: 0.0829733
# [786]	valid_0's binary_logloss: 0.082973
# [787]	valid_0's binary_logloss: 0.0829724
# [788]	valid_0's binary_logloss: 0.0829716
# [789]	valid_0's binary_logloss: 0.0829717
# [790]	valid_0's binary_logloss: 0.0829693
# [791]	valid_0's binary_logloss: 0.0829697
# [792]	valid_0's binary_logloss: 0.0829685
# [793]	valid_0's binary_logloss: 0.082968
# [794]	valid_0's binary_logloss: 0.0829682
# [795]	valid_0's binary_logloss: 0.0829673
# [796]	valid_0's binary_logloss: 0.0829662
# [797]	valid_0's binary_logloss: 0.0829669
# [798]	valid_0's binary_logloss: 0.0829673
# [799]	valid_0's binary_logloss: 0.0829655
# [800]	valid_0's binary_logloss: 0.0829656
# [801]	valid_0's binary_logloss: 0.0829662
# [802]	valid_0's binary_logloss: 0.0829664
# [803]	valid_0's binary_logloss: 0.082964
# [804]	valid_0's binary_logloss: 0.0829629
# [805]	valid_0's binary_logloss: 0.0829623
# [806]	valid_0's binary_logloss: 0.0829609
# [807]	valid_0's binary_logloss: 0.0829604
# [808]	valid_0's binary_logloss: 0.0829598
# [809]	valid_0's binary_logloss: 0.0829597
# [810]	valid_0's binary_logloss: 0.0829566
# [811]	valid_0's binary_logloss: 0.0829563
# [812]	valid_0's binary_logloss: 0.0829556
# [813]	valid_0's binary_logloss: 0.0829544
# [814]	valid_0's binary_logloss: 0.0829553
# [815]	valid_0's binary_logloss: 0.082956
# [816]	valid_0's binary_logloss: 0.0829543
# [817]	valid_0's binary_logloss: 0.0829539
# [818]	valid_0's binary_logloss: 0.0829549
# [819]	valid_0's binary_logloss: 0.0829546
# [820]	valid_0's binary_logloss: 0.0829541
# [821]	valid_0's binary_logloss: 0.082952
# [822]	valid_0's binary_logloss: 0.0829519
# [823]	valid_0's binary_logloss: 0.0829506
# [824]	valid_0's binary_logloss: 0.0829506
# [825]	valid_0's binary_logloss: 0.0829495
# [826]	valid_0's binary_logloss: 0.082949
# [827]	valid_0's binary_logloss: 0.0829483
# [828]	valid_0's binary_logloss: 0.0829466
# [829]	valid_0's binary_logloss: 0.0829472
# [830]	valid_0's binary_logloss: 0.0829466
# [831]	valid_0's binary_logloss: 0.0829457
# [832]	valid_0's binary_logloss: 0.0829467
# [833]	valid_0's binary_logloss: 0.0829476
# [834]	valid_0's binary_logloss: 0.0829489
# [835]	valid_0's binary_logloss: 0.0829489
# [836]	valid_0's binary_logloss: 0.0829492
# [837]	valid_0's binary_logloss: 0.0829474
# [838]	valid_0's binary_logloss: 0.0829472
# [839]	valid_0's binary_logloss: 0.0829464
# [840]	valid_0's binary_logloss: 0.0829456
# [841]	valid_0's binary_logloss: 0.0829463
# [842]	valid_0's binary_logloss: 0.0829448
# [843]	valid_0's binary_logloss: 0.0829444
# [844]	valid_0's binary_logloss: 0.082942
# [845]	valid_0's binary_logloss: 0.0829413
# [846]	valid_0's binary_logloss: 0.0829403
# [847]	valid_0's binary_logloss: 0.0829386
# [848]	valid_0's binary_logloss: 0.0829377
# [849]	valid_0's binary_logloss: 0.0829386
# [850]	valid_0's binary_logloss: 0.0829381
# [851]	valid_0's binary_logloss: 0.0829374
# [852]	valid_0's binary_logloss: 0.0829371
# [853]	valid_0's binary_logloss: 0.082936
# [854]	valid_0's binary_logloss: 0.0829344
# [855]	valid_0's binary_logloss: 0.0829353
# [856]	valid_0's binary_logloss: 0.082935
# [857]	valid_0's binary_logloss: 0.0829342
# [858]	valid_0's binary_logloss: 0.0829347
# [859]	valid_0's binary_logloss: 0.0829343
# [860]	valid_0's binary_logloss: 0.0829332
# [861]	valid_0's binary_logloss: 0.0829346
# [862]	valid_0's binary_logloss: 0.082933
# [863]	valid_0's binary_logloss: 0.0829329
# [864]	valid_0's binary_logloss: 0.0829313
# [865]	valid_0's binary_logloss: 0.0829322
# [866]	valid_0's binary_logloss: 0.0829319
# [867]	valid_0's binary_logloss: 0.082932
# [868]	valid_0's binary_logloss: 0.0829307
# [869]	valid_0's binary_logloss: 0.0829301
# [870]	valid_0's binary_logloss: 0.0829298
# [871]	valid_0's binary_logloss: 0.0829302
# [872]	valid_0's binary_logloss: 0.0829289
# [873]	valid_0's binary_logloss: 0.0829281
# [874]	valid_0's binary_logloss: 0.0829281
# [875]	valid_0's binary_logloss: 0.082928
# [876]	valid_0's binary_logloss: 0.0829275
# [877]	valid_0's binary_logloss: 0.0829266
# [878]	valid_0's binary_logloss: 0.0829263
# [879]	valid_0's binary_logloss: 0.0829263
# [880]	valid_0's binary_logloss: 0.0829242
# [881]	valid_0's binary_logloss: 0.0829235
# [882]	valid_0's binary_logloss: 0.082924
# [883]	valid_0's binary_logloss: 0.0829236
# [884]	valid_0's binary_logloss: 0.0829226
# [885]	valid_0's binary_logloss: 0.082924
# [886]	valid_0's binary_logloss: 0.082922
# [887]	valid_0's binary_logloss: 0.0829206
# [888]	valid_0's binary_logloss: 0.0829206
# [889]	valid_0's binary_logloss: 0.0829212
# [890]	valid_0's binary_logloss: 0.0829212
# [891]	valid_0's binary_logloss: 0.082921
# [892]	valid_0's binary_logloss: 0.0829204
# [893]	valid_0's binary_logloss: 0.0829214
# [894]	valid_0's binary_logloss: 0.0829214
# [895]	valid_0's binary_logloss: 0.0829209
# [896]	valid_0's binary_logloss: 0.0829198
# [897]	valid_0's binary_logloss: 0.0829195
# [898]	valid_0's binary_logloss: 0.0829197
# [899]	valid_0's binary_logloss: 0.0829188
# [900]	valid_0's binary_logloss: 0.082919
# [901]	valid_0's binary_logloss: 0.0829195
# [902]	valid_0's binary_logloss: 0.0829204
# [903]	valid_0's binary_logloss: 0.08292
# [904]	valid_0's binary_logloss: 0.0829206
# [905]	valid_0's binary_logloss: 0.0829207
# [906]	valid_0's binary_logloss: 0.0829201
# [907]	valid_0's binary_logloss: 0.0829218
# [908]	valid_0's binary_logloss: 0.0829218
# [909]	valid_0's binary_logloss: 0.0829207
# [910]	valid_0's binary_logloss: 0.0829202
# [911]	valid_0's binary_logloss: 0.0829212
# [912]	valid_0's binary_logloss: 0.0829205
# [913]	valid_0's binary_logloss: 0.0829206
# [914]	valid_0's binary_logloss: 0.082921
# [915]	valid_0's binary_logloss: 0.0829204
# [916]	valid_0's binary_logloss: 0.0829213
# [917]	valid_0's binary_logloss: 0.0829213
# [918]	valid_0's binary_logloss: 0.0829208
# [919]	valid_0's binary_logloss: 0.0829199
# [920]	valid_0's binary_logloss: 0.0829199
# [921]	valid_0's binary_logloss: 0.0829194
# [922]	valid_0's binary_logloss: 0.0829186
# [923]	valid_0's binary_logloss: 0.0829181
# [924]	valid_0's binary_logloss: 0.0829175
# [925]	valid_0's binary_logloss: 0.0829173
# [926]	valid_0's binary_logloss: 0.0829182
# [927]	valid_0's binary_logloss: 0.0829188
# [928]	valid_0's binary_logloss: 0.0829199
# [929]	valid_0's binary_logloss: 0.0829197
# [930]	valid_0's binary_logloss: 0.0829206
# [931]	valid_0's binary_logloss: 0.0829208
# [932]	valid_0's binary_logloss: 0.0829205
# [933]	valid_0's binary_logloss: 0.0829206
# [934]	valid_0's binary_logloss: 0.082921
# [935]	valid_0's binary_logloss: 0.0829206
# [936]	valid_0's binary_logloss: 0.0829205
# [937]	valid_0's binary_logloss: 0.0829212
# [938]	valid_0's binary_logloss: 0.0829203
# [939]	valid_0's binary_logloss: 0.0829205
# [940]	valid_0's binary_logloss: 0.0829194
# [941]	valid_0's binary_logloss: 0.0829192
# [942]	valid_0's binary_logloss: 0.0829199
# [943]	valid_0's binary_logloss: 0.0829196
# [944]	valid_0's binary_logloss: 0.0829191
# [945]	valid_0's binary_logloss: 0.0829197
# [946]	valid_0's binary_logloss: 0.08292
# [947]	valid_0's binary_logloss: 0.082919
# [948]	valid_0's binary_logloss: 0.0829193
# [949]	valid_0's binary_logloss: 0.0829207
# [950]	valid_0's binary_logloss: 0.0829219
# [951]	valid_0's binary_logloss: 0.0829224
# [952]	valid_0's binary_logloss: 0.0829222
# [953]	valid_0's binary_logloss: 0.0829226
# [954]	valid_0's binary_logloss: 0.0829212
# [955]	valid_0's binary_logloss: 0.0829201
# [956]	valid_0's binary_logloss: 0.0829205
# [957]	valid_0's binary_logloss: 0.0829206
# [958]	valid_0's binary_logloss: 0.0829199
# [959]	valid_0's binary_logloss: 0.082921
# [960]	valid_0's binary_logloss: 0.0829213
# [961]	valid_0's binary_logloss: 0.0829197
# [962]	valid_0's binary_logloss: 0.0829186
# [963]	valid_0's binary_logloss: 0.0829187
# [964]	valid_0's binary_logloss: 0.0829198
# [965]	valid_0's binary_logloss: 0.0829195
# [966]	valid_0's binary_logloss: 0.0829198
# [967]	valid_0's binary_logloss: 0.0829197
# [968]	valid_0's binary_logloss: 0.0829179
# [969]	valid_0's binary_logloss: 0.0829186
# [970]	valid_0's binary_logloss: 0.0829181
# [971]	valid_0's binary_logloss: 0.0829192
# [972]	valid_0's binary_logloss: 0.0829195
# [973]	valid_0's binary_logloss: 0.0829205
# [974]	valid_0's binary_logloss: 0.0829208
# [975]	valid_0's binary_logloss: 0.0829212
# [976]	valid_0's binary_logloss: 0.0829214
# [977]	valid_0's binary_logloss: 0.0829218
# [978]	valid_0's binary_logloss: 0.082923
# [979]	valid_0's binary_logloss: 0.0829239
# [980]	valid_0's binary_logloss: 0.0829234
# [981]	valid_0's binary_logloss: 0.082923
# [982]	valid_0's binary_logloss: 0.0829226
# [983]	valid_0's binary_logloss: 0.0829228
# [984]	valid_0's binary_logloss: 0.0829234
# [985]	valid_0's binary_logloss: 0.0829235
# [986]	valid_0's binary_logloss: 0.0829241
# [987]	valid_0's binary_logloss: 0.0829231
# [988]	valid_0's binary_logloss: 0.0829229
# [989]	valid_0's binary_logloss: 0.082925
# [990]	valid_0's binary_logloss: 0.0829253
# [991]	valid_0's binary_logloss: 0.0829246
# [992]	valid_0's binary_logloss: 0.0829235
# [993]	valid_0's binary_logloss: 0.0829235
# [994]	valid_0's binary_logloss: 0.0829235
# [995]	valid_0's binary_logloss: 0.0829234
# [996]	valid_0's binary_logloss: 0.0829221
# [997]	valid_0's binary_logloss: 0.0829215
# [998]	valid_0's binary_logloss: 0.0829205
# [999]	valid_0's binary_logloss: 0.0829205
# [1000]	valid_0's binary_logloss: 0.08292
# [1001]	valid_0's binary_logloss: 0.0829197
# [1002]	valid_0's binary_logloss: 0.0829209
# [1003]	valid_0's binary_logloss: 0.0829204
# [1004]	valid_0's binary_logloss: 0.0829197
# [1005]	valid_0's binary_logloss: 0.0829189
# [1006]	valid_0's binary_logloss: 0.0829182
# [1007]	valid_0's binary_logloss: 0.0829169
# [1008]	valid_0's binary_logloss: 0.0829174
# [1009]	valid_0's binary_logloss: 0.0829156
# [1010]	valid_0's binary_logloss: 0.0829158
# [1011]	valid_0's binary_logloss: 0.0829146
# [1012]	valid_0's binary_logloss: 0.0829134
# [1013]	valid_0's binary_logloss: 0.0829122
# [1014]	valid_0's binary_logloss: 0.0829113
# [1015]	valid_0's binary_logloss: 0.0829114
# [1016]	valid_0's binary_logloss: 0.0829113
# [1017]	valid_0's binary_logloss: 0.0829111
# [1018]	valid_0's binary_logloss: 0.0829117
# [1019]	valid_0's binary_logloss: 0.0829114
# [1020]	valid_0's binary_logloss: 0.0829119
# [1021]	valid_0's binary_logloss: 0.0829131
# [1022]	valid_0's binary_logloss: 0.0829148
# [1023]	valid_0's binary_logloss: 0.0829175
# [1024]	valid_0's binary_logloss: 0.0829179
# [1025]	valid_0's binary_logloss: 0.0829179
# [1026]	valid_0's binary_logloss: 0.0829175
# [1027]	valid_0's binary_logloss: 0.082918
# [1028]	valid_0's binary_logloss: 0.0829182
# [1029]	valid_0's binary_logloss: 0.082919
# [1030]	valid_0's binary_logloss: 0.0829194
# [1031]	valid_0's binary_logloss: 0.0829188
# [1032]	valid_0's binary_logloss: 0.0829182
# [1033]	valid_0's binary_logloss: 0.08292
# [1034]	valid_0's binary_logloss: 0.08292
# [1035]	valid_0's binary_logloss: 0.0829206
# [1036]	valid_0's binary_logloss: 0.0829208
# [1037]	valid_0's binary_logloss: 0.0829214
# [1038]	valid_0's binary_logloss: 0.082922
# [1039]	valid_0's binary_logloss: 0.082923
# [1040]	valid_0's binary_logloss: 0.0829228
# [1041]	valid_0's binary_logloss: 0.0829222
# [1042]	valid_0's binary_logloss: 0.0829218
# [1043]	valid_0's binary_logloss: 0.0829216
# [1044]	valid_0's binary_logloss: 0.0829219
# [1045]	valid_0's binary_logloss: 0.0829228
# [1046]	valid_0's binary_logloss: 0.0829231
# [1047]	valid_0's binary_logloss: 0.0829238
# [1048]	valid_0's binary_logloss: 0.0829231
# [1049]	valid_0's binary_logloss: 0.0829241
# [1050]	valid_0's binary_logloss: 0.0829264
# [1051]	valid_0's binary_logloss: 0.0829261
# [1052]	valid_0's binary_logloss: 0.0829259
# [1053]	valid_0's binary_logloss: 0.0829262
# [1054]	valid_0's binary_logloss: 0.0829264
# [1055]	valid_0's binary_logloss: 0.0829264
# [1056]	valid_0's binary_logloss: 0.0829269
# [1057]	valid_0's binary_logloss: 0.0829267
# [1058]	valid_0's binary_logloss: 0.0829266
# [1059]	valid_0's binary_logloss: 0.0829269
# [1060]	valid_0's binary_logloss: 0.0829263
# [1061]	valid_0's binary_logloss: 0.0829271
# [1062]	valid_0's binary_logloss: 0.0829276
# [1063]	valid_0's binary_logloss: 0.0829273
# [1064]	valid_0's binary_logloss: 0.0829281
# [1065]	valid_0's binary_logloss: 0.0829278
# [1066]	valid_0's binary_logloss: 0.0829283
# [1067]	valid_0's binary_logloss: 0.0829285
# [1068]	valid_0's binary_logloss: 0.0829287
# [1069]	valid_0's binary_logloss: 0.0829275
# [1070]	valid_0's binary_logloss: 0.0829274
# [1071]	valid_0's binary_logloss: 0.0829272
# [1072]	valid_0's binary_logloss: 0.0829295
# [1073]	valid_0's binary_logloss: 0.0829314
# [1074]	valid_0's binary_logloss: 0.0829311
# [1075]	valid_0's binary_logloss: 0.0829308
# [1076]	valid_0's binary_logloss: 0.0829304
# [1077]	valid_0's binary_logloss: 0.0829312
# [1078]	valid_0's binary_logloss: 0.0829318
# [1079]	valid_0's binary_logloss: 0.0829313
# [1080]	valid_0's binary_logloss: 0.0829316
# [1081]	valid_0's binary_logloss: 0.0829325
# [1082]	valid_0's binary_logloss: 0.0829331
# [1083]	valid_0's binary_logloss: 0.0829334
# [1084]	valid_0's binary_logloss: 0.0829316
# [1085]	valid_0's binary_logloss: 0.0829303
# [1086]	valid_0's binary_logloss: 0.0829301
# [1087]	valid_0's binary_logloss: 0.0829293
# [1088]	valid_0's binary_logloss: 0.0829304
# [1089]	valid_0's binary_logloss: 0.0829312
# [1090]	valid_0's binary_logloss: 0.082931
# [1091]	valid_0's binary_logloss: 0.0829315
# [1092]	valid_0's binary_logloss: 0.0829313
# [1093]	valid_0's binary_logloss: 0.0829323
# [1094]	valid_0's binary_logloss: 0.0829316
# [1095]	valid_0's binary_logloss: 0.0829329
# [1096]	valid_0's binary_logloss: 0.0829318
# [1097]	valid_0's binary_logloss: 0.0829318
# [1098]	valid_0's binary_logloss: 0.0829327
# [1099]	valid_0's binary_logloss: 0.0829329
# [1100]	valid_0's binary_logloss: 0.0829339
# [1101]	valid_0's binary_logloss: 0.0829336
# [1102]	valid_0's binary_logloss: 0.0829337
# [1103]	valid_0's binary_logloss: 0.0829335
# [1104]	valid_0's binary_logloss: 0.0829328
# [1105]	valid_0's binary_logloss: 0.0829344
# [1106]	valid_0's binary_logloss: 0.0829359
# [1107]	valid_0's binary_logloss: 0.0829354
# [1108]	valid_0's binary_logloss: 0.082936
# [1109]	valid_0's binary_logloss: 0.0829367
# [1110]	valid_0's binary_logloss: 0.082937
# [1111]	valid_0's binary_logloss: 0.0829368
# [1112]	valid_0's binary_logloss: 0.0829361
# [1113]	valid_0's binary_logloss: 0.0829353
# [1114]	valid_0's binary_logloss: 0.0829352
# [1115]	valid_0's binary_logloss: 0.0829352
# [1116]	valid_0's binary_logloss: 0.0829354
# [1117]	valid_0's binary_logloss: 0.0829372
# [1118]	valid_0's binary_logloss: 0.0829375
# [1119]	valid_0's binary_logloss: 0.0829375
# [1120]	valid_0's binary_logloss: 0.0829378
# [1121]	valid_0's binary_logloss: 0.0829378
# [1122]	valid_0's binary_logloss: 0.0829384
# [1123]	valid_0's binary_logloss: 0.0829373
# [1124]	valid_0's binary_logloss: 0.0829386
# [1125]	valid_0's binary_logloss: 0.0829389
# [1126]	valid_0's binary_logloss: 0.0829383
# [1127]	valid_0's binary_logloss: 0.0829391
# [1128]	valid_0's binary_logloss: 0.0829395
# [1129]	valid_0's binary_logloss: 0.0829414
# [1130]	valid_0's binary_logloss: 0.0829416
# [1131]	valid_0's binary_logloss: 0.0829412
# [1132]	valid_0's binary_logloss: 0.0829423
# [1133]	valid_0's binary_logloss: 0.0829416
# [1134]	valid_0's binary_logloss: 0.0829419
# [1135]	valid_0's binary_logloss: 0.0829427
# [1136]	valid_0's binary_logloss: 0.0829408
# [1137]	valid_0's binary_logloss: 0.0829412
# [1138]	valid_0's binary_logloss: 0.0829413
# [1139]	valid_0's binary_logloss: 0.0829434
# [1140]	valid_0's binary_logloss: 0.0829421
# [1141]	valid_0's binary_logloss: 0.0829412
# [1142]	valid_0's binary_logloss: 0.0829402
# [1143]	valid_0's binary_logloss: 0.0829407
# [1144]	valid_0's binary_logloss: 0.0829414
# [1145]	valid_0's binary_logloss: 0.0829422
# [1146]	valid_0's binary_logloss: 0.0829426
# [1147]	valid_0's binary_logloss: 0.0829422
# [1148]	valid_0's binary_logloss: 0.0829431
# [1149]	valid_0's binary_logloss: 0.0829431
# [1150]	valid_0's binary_logloss: 0.0829423
# [1151]	valid_0's binary_logloss: 0.0829414
# [1152]	valid_0's binary_logloss: 0.0829416
# [1153]	valid_0's binary_logloss: 0.082942
# [1154]	valid_0's binary_logloss: 0.0829426
# [1155]	valid_0's binary_logloss: 0.0829412
# [1156]	valid_0's binary_logloss: 0.0829417
# [1157]	valid_0's binary_logloss: 0.0829421
# [1158]	valid_0's binary_logloss: 0.0829443
# [1159]	valid_0's binary_logloss: 0.0829433
# [1160]	valid_0's binary_logloss: 0.0829433
# [1161]	valid_0's binary_logloss: 0.0829451
# [1162]	valid_0's binary_logloss: 0.0829458
# [1163]	valid_0's binary_logloss: 0.0829462
# [1164]	valid_0's binary_logloss: 0.0829468
# [1165]	valid_0's binary_logloss: 0.0829482
# [1166]	valid_0's binary_logloss: 0.0829495
# [1167]	valid_0's binary_logloss: 0.0829514
# Early stopping, best iteration is:
# [1017]	valid_0's binary_logloss: 0.0829111
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=0.65,
#        learning_rate=0.01, max_depth=-1, min_child_samples=20,
#        min_child_weight=0.001, min_split_gain=0.0, n_estimators=2000,
#        n_jobs=-1, num_leaves=50, objective='binary', random_state=None,
#        reg_alpha=2, reg_lambda=0.0, silent=True, subsample=0.7,
#        subsample_for_bin=200000, subsample_freq=1)

# %%
print('Start predicting...')
# predict
y_pred_1 = gbm.predict(X_val, num_iteration=gbm.best_iteration_ )
y_sub_1 = gbm.predict(X_test, num_iteration=gbm.best_iteration_ )
print()
print(log_loss(y_train,gbm.predict(X_train)))
print(log_loss(y_val,y_pred_1))

print(log_loss(y_val,(y_pred_1 + proba_val)/2))#0.0830389603803
# Out:
# Start predicting...
# D:\anaconda\lib\site-packages\lightgbm\basic.py:447: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# 0.0828100904623
# 0.0829110604181
# 0.0829405224959
