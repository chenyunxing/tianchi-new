# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
from scipy.stats import norm, skew #加载一些统计的库

# %%
data = pd.read_table('train.txt',sep=' ',index_col=False)

# %%
data2 = pd.read_csv('1234.csv',index_col=False)

# %%
data2a = pd.read_csv('two_test.csv',index_col=False)

# %%
dataa = pd.read_csv('two_train.csv',index_col=False)

# %%
data2c = pd.read_csv('test_clickpv.csv',index_col=False)

# %%
datac = pd.read_csv('clickpv.csv',index_col=False)

# %%
print(dataa.shape)
print(data2a.shape)
# Out:
# (478138, 32)
# (18371, 31)

# %%
data.insert(1, 'click', dataa[[ 'click']])
data.insert(1, 'zhuanhualv', dataa[[ 'zhuanhualv']])
data.insert(1, 'relaofzhuanhuaanddianji', dataa[[ 'relaofzhuanhuaanddianji']])
data.insert(1, 'pinpai_buy_lv', dataa[[ 'pinpai_buy_lv']])
data.insert(1, 'pinpai_click', dataa[[ 'pinpai_click']])
data.insert(1, 'clickpv', datac[[ 'clickpv']])

# %%
data.pop('item_category_list')
data.insert(1, 'item_category_list', data2[['item_category_list']])
data.pop('item_property_list')
data.insert(2, 'item_property_list', data2[['item_property_list']])
pass

# %%
data[['context_timestamp']] = data[['context_timestamp']] - 1537200000

# %%
data
# Out:
#                 instance_id  item_category_list  item_property_list  clickpv  \
# 0        108641074714126964                   2                   0     0.01
# 1       5754713551599725161                   2                   1     0.01
# 2        842679481291040981                   2                   3     0.01
# 3        937088850059189027                   2                   0     0.01
# 4       7975697065017708072                   2                   2     0.01
# 5       7764762765372067286                   2                   2     0.01
# 6       6956333474094867789                   2                   3     0.01
# 7       8387099821892927911                   2                   3     0.01
# 8       4021878205550012615                   2                   0     0.01
# 9       6499571365974135517                   2                   1     0.01
# 10      2880717957514996136                   2                   3     0.01
# 11       939825752961345523                   1                   0     0.01
# 12      8802991093903959363                   2                   0     0.01
# 13      3368094606870610045                   2                   0     0.01
# 14      7972325483281584825                   2                   3     0.01
# 15      8277925953313664420                   2                   0     0.01
# 16      6534421086843299211                   2                   1     0.01
# 17      3463502729031605090                   1                   1     0.01
# 18      8460619240681789215                   2                   3     0.01
# 19      5394134991759971072                   2                   1     0.01
# 20      8100317749857990669                   2                   0     0.01
# 21      4876117478498068156                   2                   1     0.01
# 22      7175346699535417471                   2                   0     0.01
# 23      1717647750027035965                   1                   1     0.01
# 24      3354341427042173935                   1                   1     0.01
# 25      5745320053832775381                   1                   1     0.01
# 26      5434151906459196590                   2                   1     0.01
# 27      6177436254635040085                   2                   0     0.01
# 28      5570891913513111784                   2                   0     0.01
# 29      5978989494083802018                   2                   1     0.01
# ...                     ...                 ...                 ...      ...
# 478108  4651714268781123949                   2                   1     0.04
# 478109  5390266520663927871                   2                   1     0.05
# 478110  2981469789352227651                   2                   0     0.01
# 478111  8970485803523828918                   2                   0     0.06
# 478112  3025412137450773218                   2                   0     0.04
# 478113   821625033894076557                   2                   0     0.04
# 478114  4962352896175877536                   1                   0     0.13
# 478115   613658182524644178                   2                   2     0.08
# 478116  8964303781074834102                   2                   0     0.06
# 478117  8319941530071813935                   1                   0     0.03
# 478118  6484564790810402673                   1                   0     0.06
# 478119  4127606297457513734                   2                   1     0.04
# 478120   740664466225961867                   2                   1     0.03
# 478121  7752959112678967031                   2                   2     0.06
# 478122  2960327362008121421                   1                   1     0.01
# 478123  3335455775042655938                   1                   0     0.03
# 478124  3170566302563685363                   2                   1     0.03
# 478125  6247775901908102838                   2                   2     0.02
# 478126  1104713591881111654                   2                   1     0.05
# 478127  5848988014815470928                   2                   0     0.31
# 478128  3006683903772995202                   2                   0     0.01
# 478129   810107468384208582                   2                   1     0.06
# 478130   440724230912710850                   2                   1     0.06
# 478131  5307935891681475459                   2                   4     0.01
# 478132   477737900698382237                   2                   0     0.01
# 478133  5940763769799191887                   2                   1     0.04
# 478134  3387284546470665526                   2                   0     0.08
# 478135  5693770660150212848                   2                   0     0.02
# 478136  4623253188146764341                   2                   0     0.13
# 478137  8013124750038806831                   2                   0     0.04
#
#         pinpai_click  pinpai_buy_lv  relaofzhuanhuaanddianji  zhuanhualv  \
# 0               86.0       0.000000                        2    0.000000
# 1               86.0       0.000000                        2    0.000000
# 2               86.0       0.000000                        2    0.000000
# 3               86.0       0.000000                        2    0.000000
# 4               86.0       0.000000                        2    0.000000
# 5               86.0       0.000000                        2    0.000000
# 6              171.0       0.011696                        2    0.000000
# 7              171.0       0.011696                        2    0.000000
# 8              144.0       0.006944                        2    0.000000
# 9              171.0       0.011696                        2    0.000000
# 10             171.0       0.011696                        2    0.000000
# 11             144.0       0.006944                        2    0.000000
# 12             171.0       0.011696                        2    0.000000
# 13             171.0       0.011696                        2    0.000000
# 14             171.0       0.011696                        2    0.333333
# 15             171.0       0.011696                        2    0.000000
# 16             144.0       0.006944                        2    0.000000
# 17             144.0       0.006944                        2    0.000000
# 18             171.0       0.011696                        2    0.000000
# 19             171.0       0.011696                        2    0.000000
# 20             171.0       0.011696                        2    0.000000
# 21             171.0       0.011696                        2    0.000000
# 22             144.0       0.006944                        2    0.000000
# 23             144.0       0.006944                        2    0.000000
# 24             144.0       0.006944                        2    0.000000
# 25             144.0       0.006944                        2    0.000000
# 26             171.0       0.011696                        2    0.000000
# 27             144.0       0.006944                        2    0.000000
# 28             171.0       0.011696                        2    0.000000
# 29              23.0       0.000000                        2    0.000000
# ...              ...            ...                      ...         ...
# 478108        2347.0       0.019173                        2    0.000000
# 478109        2347.0       0.019173                        2    0.000000
# 478110        2347.0       0.019173                        2    0.000000
# 478111        2347.0       0.019173                        2    0.166667
# 478112       69746.0       0.021578                        2    0.000000
# 478113       69746.0       0.021578                        2    0.000000
# 478114          21.0       0.047619                        2    0.000000
# 478115          21.0       0.047619                        2    0.000000
# 478116          67.0       0.000000                        2    0.000000
# 478117          67.0       0.000000                        2    0.000000
# 478118          67.0       0.000000                        2    0.000000
# 478119           6.0       0.000000                        2    0.000000
# 478120           6.0       0.000000                        2    0.000000
# 478121           6.0       0.000000                        2    0.000000
# 478122          70.0       0.000000                        2    0.000000
# 478123          70.0       0.000000                        2    0.000000
# 478124          70.0       0.000000                        2    0.000000
# 478125          70.0       0.000000                        2    0.000000
# 478126          70.0       0.000000                        2    0.000000
# 478127          70.0       0.000000                        2    0.000000
# 478128          70.0       0.000000                        2    0.000000
# 478129          70.0       0.000000                        2    0.000000
# 478130          70.0       0.000000                        2    0.000000
# 478131          70.0       0.042857                        2    0.000000
# 478132          70.0       0.042857                        2    1.000000
# 478133          70.0       0.042857                        2    0.000000
# 478134          70.0       0.042857                        2    0.000000
# 478135          70.0       0.042857                        2    0.000000
# 478136          70.0       0.042857                        2    0.000000
# 478137           4.0       0.000000                        2    0.000000
#
#         click              item_id    ...     context_page_id  \
# 0           6  3412720377098676069    ...                4006
# 1          10  3412720377098676069    ...                4001
# 2           2  3412720377098676069    ...                4001
# 3           1  3412720377098676069    ...                4016
# 4           2  3412720377098676069    ...                4001
# 5           8  3412720377098676069    ...                4003
# 6          23   285660928590172217    ...                4001
# 7           4   285660928590172217    ...                4001
# 8           4  5202355029344881809    ...                4001
# 9           7   285660928590172217    ...                4003
# 10          5   285660928590172217    ...                4001
# 11          1  5202355029344881809    ...                4001
# 12          2   285660928590172217    ...                4001
# 13          3   285660928590172217    ...                4003
# 14          3   285660928590172217    ...                4001
# 15          1   285660928590172217    ...                4001
# 16          2  5202355029344881809    ...                4001
# 17          1  5202355029344881809    ...                4001
# 18         14   285660928590172217    ...                4001
# 19         20   285660928590172217    ...                4001
# 20          3   285660928590172217    ...                4001
# 21          4   285660928590172217    ...                4001
# 22          3  5202355029344881809    ...                4001
# 23          1  5202355029344881809    ...                4001
# 24          1  5202355029344881809    ...                4001
# 25          2  5202355029344881809    ...                4001
# 26          1   285660928590172217    ...                4001
# 27          4  5202355029344881809    ...                4001
# 28          2   285660928590172217    ...                4003
# 29          3  4596211878136725009    ...                4010
# ...       ...                  ...    ...                 ...
# 478108      4  2288617469160644940    ...                4002
# 478109      5  2288617469160644940    ...                4001
# 478110      1  2288617469160644940    ...                4001
# 478111      6  2288617469160644940    ...                4001
# 478112      4  4667607747049310138    ...                4004
# 478113      4  2068825289180080239    ...                4002
# 478114     13  5640507991384614935    ...                4016
# 478115      8  5640507991384614935    ...                4001
# 478116      6  8724191432242434091    ...                4001
# 478117      3  8724191432242434091    ...                4013
# 478118      6  8724191432242434091    ...                4001
# 478119      4  8049642577656633945    ...                4013
# 478120      3  8049642577656633945    ...                4008
# 478121      6  8049642577656633945    ...                4002
# 478122      1  8999129345558573639    ...                4001
# 478123      3  5621212945513603977    ...                4011
# 478124      3  9184050053898973652    ...                4001
# 478125      2  5621212945513603977    ...                4001
# 478126      6   642074399208226630    ...                4001
# 478127     31  8999129345558573639    ...                4002
# 478128      1  7876305779987282497    ...                4001
# 478129      6   642074399208226630    ...                4003
# 478130      6  8714352873114629036    ...                4001
# 478131      1  5040834653196495196    ...                4001
# 478132      1  5040834653196495196    ...                4001
# 478133      4  5040834653196495196    ...                4009
# 478134      8  5040834653196495196    ...                4004
# 478135      2  5040834653196495196    ...                4001
# 478136     13  5040834653196495196    ...                4001
# 478137      4  3762437480819554366    ...                4006
#
#                                 predict_category_property  \
# 0       5799347067982556520:-1;509660095530134768:-1;5...
# 1       5799347067982556520:9172976955054793469;790838...
# 2       5799347067982556520:5131280576272319091;725801...
# 3       509660095530134768:-1;5799347067982556520:-1;7...
# 4       5799347067982556520:9172976955054793469;790838...
# 5       5799347067982556520:9172976955054793469;871073...
# 6       2011981573061447208:7199361004668592209;827733...
# 7       2011981573061447208:7199361004668592209;827733...
# 8       5755694407684602296:-1;5799347067982556520:-1;...
# 9       8277336076276184272:820214312075361939;5096600...
# 10      2011981573061447208:7199361004668592209;827733...
# 11      5799347067982556520:-1;509660095530134768:-1;7...
# 12      8277336076276184272:5131280576272319091,820214...
# 13      8277336076276184272:2636395404473730413,877809...
# 14      4879721024980945592:2636395404473730413,719936...
# 15      8277336076276184272:8778097678320011358;509660...
# 16      5755694407684602296:-1;5799347067982556520:-1;...
# 17      1760164811125093110:2253152183208719552,170013...
# 18      2011981573061447208:7199361004668592209;827733...
# 19      8277336076276184272:820214312075361939;5096600...
# 20      8277336076276184272:116615220158388148;7908382...
# 21      8277336076276184272:820214312075361939;5799347...
# 22      5755694407684602296:-1;5799347067982556520:905...
# 23      1760164811125093110:2253152183208719552,170013...
# 24      1760164811125093110:2253152183208719552,170013...
# 25      1760164811125093110:2253152183208719552,170013...
# 26      8277336076276184272:820214312075361939;5096600...
# 27      5755694407684602296:-1;5799347067982556520:905...
# 28      8277336076276184272:7199361004668592209,820214...
# 29      4879721024980945592:2636395404473730413;581450...
# ...                                                   ...
# 478108  5755694407684602296:4034352801467268686,513128...
# 478109  5755694407684602296:5131280576272319091,914848...
# 478110  5755694407684602296:1725845221699571933,403435...
# 478111  5755694407684602296:1725845221699571933,403435...
# 478112  5814506717202244251:7323906747451897092;376837...
# 478113  7314150500379498593:-1;5799347067982556520:-1;...
# 478114  5799347067982556520:2636395404473730413,657159...
# 478115  509660095530134768:2636395404473730413;8277336...
# 478116  4879721024980945592:-1;7258015885215914736:-1;...
# 478117  7258015885215914736:5131280576272319091;790838...
# 478118  7258015885215914736:2636395404473730413,153058...
# 478119  8277336076276184272:9148482949976129397;509660...
# 478120  8277336076276184272:820214312075361939;5096600...
# 478121  8277336076276184272:820214312075361939;7908382...
# 478122  2011981573061447208:-1;8277336076276184272:233...
# 478123  509660095530134768:-1;7258015885215914736:-1;5...
# 478124  2011981573061447208:-1;7447522129235776380:-1;...
# 478125  8277336076276184272:8687006518815244261;790838...
# 478126  2011981573061447208:-1;8710739180200009128:-1;...
# 478127  5755694407684602296:-1;7908382889764677758:135...
# 478128  2011981573061447208:-1;5799347067982556520:-1;...
# 478129  2011981573061447208:2636395404473730413;790838...
# 478130  2011981573061447208:-1;7447522129235776380:-1;...
# 478131  5755694407684602296:5131280576272319091;790838...
# 478132  5755694407684602296:3994732721176203348,200835...
# 478133  8257512457089702259:8895425924056041189;227312...
# 478134  5755694407684602296:-1;7908382889764677758:-1;...
# 478135      5755694407684602296:-1;7908382889764677758:-1
# 478136  8257512457089702259:-1;1760164811125093110:203...
# 478137  5755694407684602296:-1;509660095530134768:-1;8...
#
#                     shop_id  shop_review_num_level  shop_review_positive_rate  \
# 0       6765930309048922341                      4                   1.000000
# 1       6765930309048922341                      4                   1.000000
# 2       6765930309048922341                      4                   1.000000
# 3       6765930309048922341                      4                   1.000000
# 4       6765930309048922341                      4                   1.000000
# 5       6765930309048922341                      4                   1.000000
# 6       4885989684392199728                     15                   0.985427
# 7       4885989684392199728                     15                   0.985427
# 8       4885989684392199728                     15                   0.985427
# 9       4885989684392199728                     15                   0.985427
# 10      4885989684392199728                     15                   0.985427
# 11      4885989684392199728                     15                   0.985427
# 12      4885989684392199728                     15                   0.985427
# 13      4885989684392199728                     15                   0.985427
# 14      4885989684392199728                     15                   0.985427
# 15      4885989684392199728                     15                   0.985427
# 16      4885989684392199728                     15                   0.985427
# 17      4885989684392199728                     15                   0.985427
# 18      4885989684392199728                     15                   0.985427
# 19      4885989684392199728                     15                   0.985427
# 20      4885989684392199728                     15                   0.985427
# 21      4885989684392199728                     15                   0.985427
# 22      4885989684392199728                     15                   0.985427
# 23      4885989684392199728                     15                   0.985427
# 24      4885989684392199728                     15                   0.985427
# 25      4885989684392199728                     15                   0.985427
# 26      4885989684392199728                     15                   0.985427
# 27      4885989684392199728                     15                   0.985427
# 28      4885989684392199728                     15                   0.985427
# 29      6768355095170828465                     14                   0.980592
# ...                     ...                    ...                        ...
# 478108  4198248888168036410                     13                   1.000000
# 478109  4198248888168036410                     13                   1.000000
# 478110  4198248888168036410                     13                   1.000000
# 478111  4198248888168036410                     13                   1.000000
# 478112  7997345702288694802                     10                   0.996195
# 478113    45677417567331780                     14                   0.996806
# 478114  7347575640411812711                     13                   0.989632
# 478115  7347575640411812711                     13                   0.989632
# 478116  7780498762051975900                     11                   0.998704
# 478117  7780498762051975900                     11                   0.998704
# 478118  7780498762051975900                     11                   0.998704
# 478119  2670214922754946056                     10                   0.974884
# 478120  2670214922754946056                     10                   0.974884
# 478121  2670214922754946056                     10                   0.974884
# 478122  3003432921423401154                     16                   1.000000
# 478123  3003432921423401154                     16                   1.000000
# 478124  3003432921423401154                     16                   1.000000
# 478125  3003432921423401154                     16                   1.000000
# 478126  3003432921423401154                     16                   1.000000
# 478127  3003432921423401154                     16                   1.000000
# 478128  3003432921423401154                     16                   1.000000
# 478129  3003432921423401154                     16                   1.000000
# 478130  3003432921423401154                     16                   1.000000
# 478131  6642568563427911256                     16                   0.993662
# 478132  6642568563427911256                     16                   0.993662
# 478133  6642568563427911256                     16                   0.993662
# 478134  6642568563427911256                     16                   0.993662
# 478135  6642568563427911256                     16                   0.993662
# 478136  6642568563427911256                     16                   0.993662
# 478137  7591475337333430247                     10                   0.991431
#
#         shop_star_level  shop_score_service  shop_score_delivery  \
# 0                  5002            1.000000             1.000000
# 1                  5002            1.000000             1.000000
# 2                  5002            1.000000             1.000000
# 3                  5002            1.000000             1.000000
# 4                  5002            1.000000             1.000000
# 5                  5002            1.000000             1.000000
# 6                  5012            0.974878             0.976863
# 7                  5012            0.974878             0.976863
# 8                  5012            0.974878             0.976863
# 9                  5012            0.974878             0.976863
# 10                 5012            0.974878             0.976863
# 11                 5012            0.974878             0.976863
# 12                 5012            0.974878             0.976863
# 13                 5012            0.974878             0.976863
# 14                 5012            0.974878             0.976863
# 15                 5012            0.974878             0.976863
# 16                 5012            0.974878             0.976863
# 17                 5012            0.974878             0.976863
# 18                 5012            0.974878             0.976863
# 19                 5012            0.974878             0.976863
# 20                 5012            0.974878             0.976863
# 21                 5012            0.974878             0.976863
# 22                 5012            0.974878             0.976863
# 23                 5012            0.974878             0.976863
# 24                 5012            0.974878             0.976863
# 25                 5012            0.974878             0.976863
# 26                 5012            0.974878             0.976863
# 27                 5012            0.974878             0.976863
# 28                 5012            0.974878             0.976863
# 29                 5012            0.972680             0.972113
# ...                 ...                 ...                  ...
# 478108             5011            0.972676             0.969388
# 478109             5011            0.972676             0.969388
# 478110             5011            0.972676             0.969388
# 478111             5011            0.972676             0.969388
# 478112             5008            0.981656             0.981656
# 478113             5011            0.980664             0.981072
# 478114             5011            0.984251             0.985088
# 478115             5011            0.984251             0.985088
# 478116             5009            0.986071             0.986071
# 478117             5009            0.986071             0.986071
# 478118             5009            0.986071             0.986071
# 478119             5008            0.968842             0.972772
# 478120             5008            0.968842             0.972772
# 478121             5008            0.968842             0.972772
# 478122             5013            0.977327             0.977367
# 478123             5013            0.977327             0.977367
# 478124             5013            0.977327             0.977367
# 478125             5013            0.977327             0.977367
# 478126             5013            0.977327             0.977367
# 478127             5013            0.977327             0.977367
# 478128             5013            0.977327             0.977367
# 478129             5013            0.977327             0.977367
# 478130             5013            0.977327             0.977367
# 478131             5014            0.950846             0.950738
# 478132             5014            0.950846             0.950738
# 478133             5014            0.950846             0.950738
# 478134             5014            0.950846             0.950738
# 478135             5014            0.950846             0.950738
# 478136             5014            0.950846             0.950738
# 478137             5008            0.894010             0.886656
#
#         shop_score_description  is_trade
# 0                     1.000000         0
# 1                     1.000000         0
# 2                     1.000000         0
# 3                     1.000000         0
# 4                     1.000000         0
# 5                     1.000000         0
# 6                     0.969278         0
# 7                     0.969278         0
# 8                     0.969278         0
# 9                     0.969278         0
# 10                    0.969278         0
# 11                    0.969278         0
# 12                    0.969278         0
# 13                    0.969278         0
# 14                    0.969278         1
# 15                    0.969278         0
# 16                    0.969278         0
# 17                    0.969278         0
# 18                    0.969278         0
# 19                    0.969278         0
# 20                    0.969278         0
# 21                    0.969278         0
# 22                    0.969278         0
# 23                    0.969278         0
# 24                    0.969278         0
# 25                    0.969278         0
# 26                    0.969278         0
# 27                    0.969278         0
# 28                    0.969278         0
# 29                    0.970680         0
# ...                        ...       ...
# 478108                0.985169         0
# 478109                0.985169         0
# 478110                0.985169         0
# 478111                0.985169         0
# 478112                0.973898         0
# 478113                0.968681         0
# 478114                0.981588         0
# 478115                0.981588         0
# 478116                0.980612         0
# 478117                0.980612         0
# 478118                0.980612         0
# 478119                0.963789         0
# 478120                0.963789         0
# 478121                0.963789         0
# 478122                0.979027         0
# 478123                0.979027         0
# 478124                0.979027         0
# 478125                0.979027         0
# 478126                0.979027         0
# 478127                0.979027         0
# 478128                0.979027         0
# 478129                0.979027         0
# 478130                0.979027         0
# 478131                0.945286         0
# 478132                0.945286         1
# 478133                0.945286         0
# 478134                0.945286         0
# 478135                0.945286         0
# 478136                0.945286         0
# 478137                0.879810         0
#
# [478138 rows x 33 columns]

# %%
X = data[[ 
          'shop_review_positive_rate','shop_score_service',
         'shop_score_delivery','shop_score_description','shop_star_level'
          ,'shop_review_num_level','item_price_level','item_sales_level',
         'item_collected_level','item_pv_level',
          'user_gender_id','user_age_level',
          'user_occupation_id','user_star_level',
          'context_page_id','context_timestamp',
            'relaofzhuanhuaanddianji', 'click', 'pinpai_click','clickpv']]
Y = data[['is_trade']]
X = np.array(X)
Y = np.array(Y).ravel()

# %%
# 制作训练集与测试集并且进行预处理
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import OneHotEncoder
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=666)

# %%
# X_shop_train = X_train[:, :6]
# X_item_train = X_train[:, 6:10]
# X_user_train = X_train[:, 10:13]
# X_content_train = X_train[:, 13:15]
# X_shop_test = X_test[:, :6]
# X_item_test = X_test[:, 6:10]
# X_user_test = X_test[:, 10:13]
# X_content_test = X_test[:, 13:15]

# %%
train = X_train
test = X_test

# %% [markdown]
# ## 加载测试集

# %%
data2 = pd.read_table('test.txt',sep=' ',index_col=False)

# %%
data3 = pd.read_csv('456.csv',index_col=False)

# %%
data2.insert(1, 'click', data2a[[ 'click']])
data2.insert(1, 'zhuanhualv', data2a[['zhuanhualv']])
data2.insert(1, 'relaofzhuanhuaanddianji', data2a[[ 'relaofzhuanhuaanddianji']])
data2.insert(1, 'pinpai_buy_lv', data2a[[ 'pinpai_buy_lv']])
data2.insert(1, 'pinpai_click', data2a[[ 'pinpai_click']])
data2.insert(1, 'clickpv', data2c[[ 'clickpv']])

# %%
data2.pop('item_category_list')
data2.insert(1, 'item_category_list', data3[['item_category_list']])
data2.pop('item_property_list')
data2.insert(2, 'item_property_list', data3[['item_property_list']])
pass

# %%
data2[['context_timestamp']] = data2[['context_timestamp']] - 1537200000

# %%
data2a.columns
# Out:
# Index(['instance_id', 'item_id', 'item_category_list', 'item_property_list',
#        'item_brand_id', 'item_city_id', 'item_price_level', 'item_sales_level',
#        'item_collected_level', 'item_pv_level', 'user_id', 'user_gender_id',
#        'user_age_level', 'user_occupation_id', 'user_star_level', 'context_id',
#        'context_timestamp', 'context_page_id', 'predict_category_property',
#        'shop_id', 'shop_review_num_level', 'shop_review_positive_rate',
#        'shop_star_level', 'shop_score_service', 'shop_score_delivery',
#        'shop_score_description', 'click', 'zhuanhualv',
#        'relaofzhuanhuaanddianji', 'pinpai_click', 'pinpai_buy_lv'],
#       dtype='object')

# %%
# X_pre = data2[['item_category_list','item_property_list',
#           'zhuanhualv','relaofzhuanhuaanddianji', 
#           'pinpai_buy_lv', 'pinpai_click',
#           'shop_review_positive_rate','shop_score_service',
#          'shop_score_delivery','shop_score_description','shop_star_level'
#           ,'shop_review_num_level','item_price_level','item_sales_level',
#          'item_collected_level','item_pv_level',
#           'user_gender_id','user_age_level',
#           'user_occupation_id','user_star_level',
#           'context_page_id','context_timestamp']]
X_pre = data2[[ 
          'shop_review_positive_rate','shop_score_service',
         'shop_score_delivery','shop_score_description','shop_star_level'
          ,'shop_review_num_level','item_price_level','item_sales_level',
         'item_collected_level','item_pv_level',
          'user_gender_id','user_age_level',
          'user_occupation_id','user_star_level',
          'context_page_id','context_timestamp',
            'relaofzhuanhuaanddianji', 'click', 'pinpai_click','clickpv']]
X_pre = np.array(X_pre,dtype='float')

# %%
X_pre[10,:]
# Out:
# array([  1.00000000e+00,   9.79252459e-01,   9.80537705e-01,
#          9.85626230e-01,   5.01200000e+03,   1.50000000e+01,
#          8.00000000e+00,   1.00000000e+01,   1.30000000e+01,
#          1.50000000e+01,   1.00000000e+00,   1.00200000e+03,
#          2.00500000e+03,   3.00700000e+03,   4.00100000e+03,
#          6.66277000e+05,   0.00000000e+00,   0.00000000e+00,
#          1.16000000e+02,   1.00000000e-02])

# %% [markdown]
# ## 分箱

# %%
#item_price_level
# bins = np.linspace(-0.5, 2.5, 4)
sha = train.shape[1]
for i in range(4,sha-5):
# i = 4
# if True:
    print((X_train[:,i][X_train[:,i]>=0].max()+1.5)-(X_train[:,i][X_train[:,i]>=0].min()-0.5))
    bins = np.arange(X_train[:,i][(X_train[:,i]>=0)].min()-0.5, X_train[:,i][X_train[:,i]>=0].max()+1.5, 1)
    bins = np.hstack(([-1.5],bins))
    which_bin = np.digitize(train[:,i].reshape(-1, 1), bins=bins)
    encoder = OneHotEncoder(sparse=False)
    encoder.fit(which_bin)
    X_train_binned = encoder.transform(which_bin)



    which_bin = np.digitize(test[:,i].reshape(-1, 1), bins=bins)
#     encoder = OneHotEncoder(sparse=False)
#     encoder.fit(which_bin)
    X_test_binned = encoder.transform(which_bin)
    
    which_bin = np.digitize(X_pre[:,i].reshape(-1, 1), bins=bins)
#     encoder = OneHotEncoder(sparse=False)
#     encoder.fit(which_bin)
    X_pre_binned = encoder.transform(which_bin)
    print(bins)
    if (np.hstack((train,X_train_binned)).shape[1] == np.hstack((test,X_test_binned)).shape[1]):
        if (np.hstack((X_pre,X_pre_binned)).shape[1] == np.hstack((test,X_test_binned)).shape[1]):
            train = np.hstack((train,X_train_binned))
            test = np.hstack((test,X_test_binned))
            X_pre = np.hstack((X_pre,X_pre_binned))
            print("0k")
    else:
        print("No")
# Out:
# 23.0
# [ -1.50000000e+00   4.99850000e+03   4.99950000e+03   5.00050000e+03
#    5.00150000e+03   5.00250000e+03   5.00350000e+03   5.00450000e+03
#    5.00550000e+03   5.00650000e+03   5.00750000e+03   5.00850000e+03
#    5.00950000e+03   5.01050000e+03   5.01150000e+03   5.01250000e+03
#    5.01350000e+03   5.01450000e+03   5.01550000e+03   5.01650000e+03
#    5.01750000e+03   5.01850000e+03   5.01950000e+03   5.02050000e+03]
# 0k
# 27.0
# [ -1.5  -0.5   0.5   1.5   2.5   3.5   4.5   5.5   6.5   7.5   8.5   9.5
#   10.5  11.5  12.5  13.5  14.5  15.5  16.5  17.5  18.5  19.5  20.5  21.5
#   22.5  23.5  24.5  25.5]
# 0k
# 19.0
# [ -1.5  -0.5   0.5   1.5   2.5   3.5   4.5   5.5   6.5   7.5   8.5   9.5
#   10.5  11.5  12.5  13.5  14.5  15.5  16.5  17.5]
# 0k
# 18.0
# [ -1.5   0.5   1.5   2.5   3.5   4.5   5.5   6.5   7.5   8.5   9.5  10.5
#   11.5  12.5  13.5  14.5  15.5  16.5  17.5]
# 0k
# 19.0
# [ -1.5  -0.5   0.5   1.5   2.5   3.5   4.5   5.5   6.5   7.5   8.5   9.5
#   10.5  11.5  12.5  13.5  14.5  15.5  16.5  17.5]
# 0k
# 23.0
# [ -1.5  -0.5   0.5   1.5   2.5   3.5   4.5   5.5   6.5   7.5   8.5   9.5
#   10.5  11.5  12.5  13.5  14.5  15.5  16.5  17.5  18.5  19.5  20.5  21.5]
# 0k
# 4.0
# [-1.5 -0.5  0.5  1.5  2.5]
# 0k
# 9.0
# [   -1.5   999.5  1000.5  1001.5  1002.5  1003.5  1004.5  1005.5  1006.5
#   1007.5]
# 0k
# 5.0
# [ -1.50000000e+00   2.00150000e+03   2.00250000e+03   2.00350000e+03
#    2.00450000e+03   2.00550000e+03]
# 0k
# 12.0
# [ -1.50000000e+00   2.99950000e+03   3.00050000e+03   3.00150000e+03
#    3.00250000e+03   3.00350000e+03   3.00450000e+03   3.00550000e+03
#    3.00650000e+03   3.00750000e+03   3.00850000e+03   3.00950000e+03
#    3.01050000e+03]
# 0k
# 21.0
# [ -1.50000000e+00   4.00050000e+03   4.00150000e+03   4.00250000e+03
#    4.00350000e+03   4.00450000e+03   4.00550000e+03   4.00650000e+03
#    4.00750000e+03   4.00850000e+03   4.00950000e+03   4.01050000e+03
#    4.01150000e+03   4.01250000e+03   4.01350000e+03   4.01450000e+03
#    4.01550000e+03   4.01650000e+03   4.01750000e+03   4.01850000e+03
#    4.01950000e+03   4.02050000e+03]
# 0k

# %%
bins = np.linspace(0, 86400,49)
print(bins)
bins = np.hstack(([-1.5],bins))
which_bin = np.digitize(train[:,15].reshape(-1, 1), bins=bins)
encoder = OneHotEncoder(sparse=False)
encoder.fit(which_bin)
X_train_binned = encoder.transform(which_bin)



which_bin = np.digitize(test[:,15].reshape(-1, 1), bins=bins)
# encoder = OneHotEncoder(sparse=False)
# encoder.fit(which_bin)
X_test_binned = encoder.transform(which_bin)

which_bin = np.digitize(X_pre[:,15].reshape(-1, 1), bins=bins)
# encoder = OneHotEncoder(sparse=False)
# encoder.fit(which_bin)
X_pre_binned = encoder.transform(which_bin)
print(bins)
if (np.hstack((train,X_train_binned)).shape[1] == np.hstack((test,X_test_binned)).shape[1]):
    if (np.hstack((X_pre,X_pre_binned)).shape[1] == np.hstack((test,X_test_binned)).shape[1]):
        train = np.hstack((train,X_train_binned))
        test = np.hstack((test,X_test_binned))
        X_pre = np.hstack((X_pre,X_pre_binned))
        print("0k")
else:
    print("No")
# Out:
# [     0.   1800.   3600.   5400.   7200.   9000.  10800.  12600.  14400.
#   16200.  18000.  19800.  21600.  23400.  25200.  27000.  28800.  30600.
#   32400.  34200.  36000.  37800.  39600.  41400.  43200.  45000.  46800.
#   48600.  50400.  52200.  54000.  55800.  57600.  59400.  61200.  63000.
#   64800.  66600.  68400.  70200.  72000.  73800.  75600.  77400.  79200.
#   81000.  82800.  84600.  86400.]
# [ -1.50000000e+00   0.00000000e+00   1.80000000e+03   3.60000000e+03
#    5.40000000e+03   7.20000000e+03   9.00000000e+03   1.08000000e+04
#    1.26000000e+04   1.44000000e+04   1.62000000e+04   1.80000000e+04
#    1.98000000e+04   2.16000000e+04   2.34000000e+04   2.52000000e+04
#    2.70000000e+04   2.88000000e+04   3.06000000e+04   3.24000000e+04
#    3.42000000e+04   3.60000000e+04   3.78000000e+04   3.96000000e+04
#    4.14000000e+04   4.32000000e+04   4.50000000e+04   4.68000000e+04
#    4.86000000e+04   5.04000000e+04   5.22000000e+04   5.40000000e+04
#    5.58000000e+04   5.76000000e+04   5.94000000e+04   6.12000000e+04
#    6.30000000e+04   6.48000000e+04   6.66000000e+04   6.84000000e+04
#    7.02000000e+04   7.20000000e+04   7.38000000e+04   7.56000000e+04
#    7.74000000e+04   7.92000000e+04   8.10000000e+04   8.28000000e+04
#    8.46000000e+04   8.64000000e+04]
# 0k

# %%
test.shape
# Out:
# (119535, 238)

# %%
# PF = PolynomialFeatures(degree=2)
# PF.fit(train)
# X_train = PF.transform(train)
# X_test = PF.transform(test)

# %%
SS = StandardScaler()
SS.fit(train)
train = SS.transform(train)
test = SS.transform(test)
X_pre = SS.transform(X_pre)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.externals import joblib
from sklearn.metrics import log_loss
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC

import xgboost as xgb
import lightgbm as lgb

# %%
xgb?

# %%
model_xgb = xgb.XGBClassifier( n_estimators=400,random_state =666, nthread = -1,n_jobs=-1)

# %%
model_xgb.fit(train, Y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=400,
#        n_jobs=-1, nthread=-1, objective='binary:logistic',
#        random_state=666, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)

# %%
xgb_train_pred = model_xgb.predict_proba(train)
log_loss(Y_train, xgb_train_pred[:,1])
# Out:
# 0.086127390526280198

# %%
xgb_test_pred = model_xgb.predict_proba(test)
log_loss(Y_test, xgb_test_pred[:,1])
# Out:
# 0.087471731894863

# %%
model_xgb.predict_proba(X_pre)[:,1]
# Out:
# array([ 0.00464319,  0.00950932,  0.01936598, ...,  0.00799046,
#         0.0410134 ,  0.01485141], dtype=float32)

# %%
874
# Out:
# 874

# %%
xgb1 = model_xgb

# %%
model_lgb = lgb.LGBMClassifier(n_estimators=100,n_jobs=-1,min_child_samples=500,
                              feature_fraction_seed=666, bagging_seed=666)

# %%
model_lgb.fit(train, Y_train)
# Out:
# LGBMClassifier(bagging_seed=666, boosting_type='gbdt', class_weight=None,
#         colsample_bytree=1.0, feature_fraction_seed=666, learning_rate=0.1,
#         max_depth=-1, min_child_samples=500, min_child_weight=0.001,
#         min_split_gain=0.0, n_estimators=100, n_jobs=-1, num_leaves=31,
#         objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=1)

# %%
lgb_train_pred = model_lgb.predict_proba(train)
log_loss(Y_train, lgb_train_pred[:,1])
# Out:
# 0.085268233412610805

# %%
lgb_test_pred = model_lgb.predict_proba(test)
log_loss(Y_test, lgb_test_pred[:,1])
# Out:
# 0.087338022442155896

# %%
model_lgb.predict_proba(X_pre)[:,1]
# Out:
# array([ 0.00480042,  0.02034508,  0.02861821, ...,  0.02615311,
#         0.07096084,  0.02628773])

# %%
876
# Out:
# 876

# %%
lgb_test_pred = model_lgb.predict_proba(test)
xgb_test_pred = model_xgb.predict_proba(test)
log_loss(Y_test, (xgb_test_pred[:,1]+xgb_test_pred[:,1])/2)
# Out:
# 0.087471731894863

# %%
log_loss(Y_test, (xgb_test_pred[:,1]+xgb_test_pred[:,1])/2)
# Out:
# 0.087471731894863

# %%
log_reg = LogisticRegression(C = 0.01,penalty='l1')
log_reg.fit(train, Y_train)
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
log_loss(Y_train, log_reg.predict_proba(train)[:,1])
# Out:
# 0.089838289612323471

# %%
log_loss(Y_test, log_reg.predict_proba(test)[:,1])
# Out:
# 0.08838262200701745

# %%
log_reg.predict_proba(test)[:,1]
# Out:
# array([ 0.00854885,  0.02639892,  0.01250593, ...,  0.03293847,
#         0.01413626,  0.02508614])

# %%
lgb_test_pred = model_lgb.predict_proba(train)
xgb_test_pred = model_xgb.predict_proba(train)
X_add = np.hstack((lgb_test_pred, xgb_test_pred))

# %%
log_all = LogisticRegression()
log_all.fit(X_add, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
log_loss(Y_train, log_all.predict_proba(X_add)[:,1])
# Out:
# 0.08711101159725583

# %%
lgb_test_pred = model_lgb.predict_proba(test)
xgb_test_pred = model_xgb.predict_proba(test)
X_add = np.hstack((lgb_test_pred, xgb_test_pred))

# %%
log_loss(Y_test, log_all.predict_proba(X_add)[:,1])
# Out:
# 0.088584669613493622

# %%
lgb_test_pred = model_lgb.predict_proba(test)
xgb_test_pred = model_xgb.predict_proba(test)
X_add = np.hstack((lgb_test_pred, xgb_test_pred))

# %%
log_loss(Y_test, log_all.predict_proba(X_add)[:,1])
# Out:
# 0.089675369764396301

# %%
# BC = BaggingClassifier(base_estimator=LogisticRegression(C = 0.01), random_state=666, n_estimators=30)
# BC.fit(train, Y_train)

# %%
# log_loss(Y_train, BC.predict_proba(train))

# %%
# log_loss(Y_test, BC.predict_proba(test))

# %%
# log_reg.predict_proba(train)[:,1]

# %%
# ETR = joblib.load('allETR.pkl')
# ETR = ExtraTreesClassifier(n_estimators=300, n_jobs=-1, random_state=666, max_depth=500)#0.41
# ETR.fit(train, Y_train)

# %%
# log_loss(Y_train, ETR.predict_proba(train)[:,1])

# %%
# log_loss(Y_test, ETR.predict_proba(test)[:,1])

# %%
# joblib.dump(ETR, 'allETR.pkl')

# %%
MNB = MultinomialNB(alpha=1)
MNB.fit(train+1, Y_train)
# Out:
# MultinomialNB(alpha=1, class_prior=None, fit_prior=True)

# %%
log_loss(Y_test, MNB.predict_proba(test+1)[:,1])
# Out:
# 16.115579524976997

# %%
BNB = BernoulliNB(alpha=1)
BNB.fit(train+1, Y_train)
# Out:
# BernoulliNB(alpha=1, binarize=0.0, class_prior=None, fit_prior=True)

# %%
log_loss(Y_test, BNB.predict_proba(test)[:,1])
# Out:
# 33.901286592858881

# %%
log_loss(Y_test, np.ones([Y_test.shape[0],1])*0.01*4)
# Out:
# 0.099552248514805805

# %%
np.ones([Y_test.shape[0],1])*0.000000001*4
# Out:
# array([[  4.00000000e-09],
#        [  4.00000000e-09],
#        [  4.00000000e-09],
#        ...,
#        [  4.00000000e-09],
#        [  4.00000000e-09],
#        [  4.00000000e-09]])

# %%
np.zeros([Y_test.shape[0],1])
# Out:
# array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]])

# %%
# last = LogisticRegression(C = 0.0008,penalty='l2')

# # log_reg.fit(train, Y_train)
# # ETR.fit(train, Y_train)
# # MNB.fit(train+1, Y_train)
# # BNB.fit(train+1, Y_train)
# c_data = log_reg.predict_proba(train)[:, 1].reshape(-1, 1)
# c_data = np.hstack((c_data,ETR.predict_proba(train)[:, 1].reshape(-1, 1)))
# c_data = np.hstack((c_data,MNB.predict_proba(train+1)[:, 1].reshape(-1, 1)))
# # c_data = np.hstack((c_data,BNB.predict_proba(train+1)[:, 1].reshape(-1, 1)))
# last.fit(c_data,Y_train)

# %%
# Y_pre1 = log_reg.predict_proba(train)[:, 1].reshape(-1, 1)
# Y_pre2 = ETR.predict_proba(train)[:, 1].reshape(-1, 1)
# Y_pre3 = MNB.predict_proba(train+1)[:, 1].reshape(-1, 1)
# # Y_pre4 = BNB.predict_proba(train+1)[:, 1].reshape(-1, 1)
# Y_add = np.hstack((Y_pre1, Y_pre2))
# Y_add = np.hstack((Y_add, Y_pre3))
# # Y_add = np.hstack((Y_add, Y_pre4))
# Y_pre = last.predict_proba(Y_add)

# %%
# log_loss(Y_train, Y_pre)

# %%
# log_loss(Y_test, last.predict_proba(np.hstack((log_reg.predict_proba(test)[:, 1].reshape(-1, 1),ETR.predict_proba(test)[:, 1].reshape(-1, 1)))))

# %%
# Y_pre1 = log_reg.predict_proba(test)[:, 1].reshape(-1, 1)
# Y_pre2 = ETR.predict_proba(test)[:, 1].reshape(-1, 1)
# Y_pre3 = MNB.predict_proba(test+1)[:, 1].reshape(-1, 1)
# # Y_pre4 = BNB.predict_proba(test+1)[:, 1].reshape(-1, 1)
# Y_add = np.hstack((Y_pre1, Y_pre2))
# Y_add = np.hstack((Y_add, Y_pre3))
# # Y_add = np.hstack((Y_add, Y_pre4))
# Y_pre = last.predict_proba(Y_add)

# # Y_pre = Y_pre1 + Y_pre2 + Y_pre3 + Y_pre4
# # Y_pre = Y_pre/4

# %%
# log_loss(Y_test, Y_pre)

# %%
# Y_pre = ETR.predict_proba(X_pre)
# Y_pre

# %%
Y_pre = log_reg.predict_proba(X_pre)[:,1]
Y_pre = Y_pre.reshape(-1,1)
Y_prelist = Y_pre.tolist()

# %%
Y_prelist
# Out:
# [[0.0046431878581643105],
#  [0.009509317576885223],
#  [0.019365979358553886],
#  [0.02037646248936653],
#  [0.012052217498421669],
#  [0.008960563689470291],
#  [0.036466311663389206],
#  [0.008568317629396915],
#  [0.005505737382918596],
#  [0.006846429314464331],
#  [0.005981637164950371],
#  [0.005664622411131859],
#  [0.004932793322950602],
#  [0.0210989098995924],
#  [0.0071770139038562775],
#  [0.006416521966457367],
#  [0.005068987142294645],
#  [0.011705668643116951],
#  [0.0067966170608997345],
#  [0.008868664503097534],
#  [0.02161259949207306],
#  [0.002675173105672002],
#  [0.001457499573007226],
#  [0.0018567921360954642],
#  [0.0034473470877856016],
#  [0.00159956025891006],
#  [0.001964984927326441],
#  [0.00156093155965209],
#  [0.002456458518281579],
#  [0.0033379392698407173],
#  [0.002155508380383253],
#  [0.003286865772679448],
#  [0.001457499573007226],
#  [0.0038271641824394464],
#  [0.002819944405928254],
#  [0.0011488309828564525],
#  [0.0034898673184216022],
#  [0.002108408370986581],
#  [0.0031373538076877594],
#  [0.002434496534988284],
#  [0.0022988051641732454],
#  [0.003464793087914586],
#  [0.002435629488900304],
#  [0.0031413172837346792],
#  [0.0032302329782396555],
#  [0.0024374653585255146],
#  [0.001271518412977457],
#  [0.0014592028455808759],
#  [0.002352722454816103],
#  [0.003211870789527893],
#  [0.0022753996308892965],
#  [0.002020108513534069],
#  [0.0045099337585270405],
#  [0.004302128218114376],
#  [0.006124705076217651],
#  [0.0015249265125021338],
#  [0.0027493068482726812],
#  [0.0016861774493008852],
#  [0.0018613445572555065],
#  [0.002178874099627137],
#  [0.0015812411438673735],
#  [0.0011673109838739038],
#  [0.0031417503487318754],
#  [0.0025832054670900106],
#  [0.004648186732083559],
#  [0.0031597039196640253],
#  [0.0022162937093526125],
#  [0.0031491585541516542],
#  [0.0026560716796666384],
#  [0.0019278224790468812],
#  [0.003997974097728729],
#  [0.002171202562749386],
#  [0.001786152133718133],
#  [0.0019924782682210207],
#  [0.002155508380383253],
#  [0.002098832046613097],
#  [0.0007833671406842768],
#  [0.0025357420090585947],
#  [0.004272820893675089],
#  [0.001923904288560152],
#  [0.0027831937186419964],
#  [0.002595476107671857],
#  [0.002644267166033387],
#  [0.0015356197254732251],
#  [0.0028259647078812122],
#  [0.0065690455958247185],
#  [0.0025507546961307526],
#  [0.0013298519188538194],
#  [0.0017432060558348894],
#  [0.0040189647115767],
#  [0.0038591395132243633],
#  [0.0017784498631954193],
#  [0.003182494081556797],
#  [0.002386273816227913],
#  [0.001716681756079197],
#  [0.002236089436337352],
#  [0.0034857208374887705],
#  [0.002429821528494358],
#  [0.0018367706798017025],
#  [0.0023261650931090117],
#  [0.0012059026630595326],
#  [0.0016791911330074072],
#  [0.003785518929362297],
#  [0.002516342094168067],
#  [0.0013115478213876486],
#  [0.001685366965830326],
#  [0.005322103854268789],
#  [0.00331600452773273],
#  [0.0021442172583192587],
#  [0.0018957802094519138],
#  [0.002328539965674281],
#  [0.0027493734378367662],
#  [0.0010610446333885193],
#  [0.0033650705590844154],
#  [0.0018330372404307127],
#  [0.0021936900448054075],
#  [0.0024064071476459503],
#  [0.0022240851540118456],
#  [0.0008325695525854826],
#  [0.0036527160555124283],
#  [0.001617689966224134],
#  [0.0017737984890118241],
#  [0.003828589804470539],
#  [0.0021590085234493017],
#  [0.001528435735963285],
#  [0.00271148351021111],
#  [0.0019224561983719468],
#  [0.004340873099863529],
#  [0.0038946319837123156],
#  [0.0027390369214117527],
#  [0.0013901229249313474],
#  [0.002889776136726141],
#  [0.0020502712577581406],
#  [0.004437167663127184],
#  [0.0034149866551160812],
#  [0.002709900727495551],
#  [0.0017021592939272523],
#  [0.001108494121581316],
#  [0.002294514561071992],
#  [0.002155508380383253],
#  [0.0024296308401972055],
#  [0.002294514561071992],
#  [0.0015258531784638762],
#  [0.0015899105928838253],
#  [0.001968040596693754],
#  [0.002531329169869423],
#  [0.0007272765506058931],
#  [0.0005077536916360259],
#  [0.0025357420090585947],
#  [0.0016273228684440255],
#  [0.0029410545248538256],
#  [0.002437122166156769],
#  [0.0010312441736459732],
#  [0.0022329213097691536],
#  [0.00215856172144413],
#  [0.0024827299639582634],
#  [0.0026221654843539],
#  [0.0017292849952355027],
#  [0.0013871031114831567],
#  [0.0016436964506283402],
#  [0.00188462866935879],
#  [0.002020108513534069],
#  [0.004099123179912567],
#  [0.003583498764783144],
#  [0.0026447728741914034],
#  [0.0016605034470558167],
#  [0.002437122166156769],
#  [0.0016205860301852226],
#  [0.0073100202716887],
#  [0.0026447728741914034],
#  [0.0021064747124910355],
#  [0.002513461746275425],
#  [0.002008190844208002],
#  [0.006591195706278086],
#  [0.00185951788444072],
#  [0.0011690018000081182],
#  [0.005034634843468666],
#  [0.0014538862742483616],
#  [0.002777616959065199],
#  [0.0018211276037618518],
#  [0.0021087995264679193],
#  [0.0028242601547390223],
#  [0.0037358461413532495],
#  [0.0019750529900193214],
#  [0.0027291597798466682],
#  [0.0022104838863015175],
#  [0.002155508380383253],
#  [0.0013713169610127807],
#  [0.0014120700070634484],
#  [0.0016346345655620098],
#  [0.0011852950556203723],
#  [0.00426025316119194],
#  [0.006283849012106657],
#  [0.0009784389985725284],
#  [0.0011683505726978183],
#  [0.002156567992642522],
#  [0.0015210820129141212],
#  [0.003165837610140443],
#  [0.0033511128276586533],
#  [0.002328539965674281],
#  [0.00236589671112597],
#  [0.0031633360777050257],
#  [0.0019284666050225496],
#  [0.0034328815527260303],
#  [0.002155508380383253],
#  [0.002781505696475506],
#  [0.0015072835376486182],
#  [0.0016379685839638114],
#  [0.003210097085684538],
#  [0.003352648578584194],
#  [0.0035516954958438873],
#  [0.004417566582560539],
#  [0.00209254352375865],
#  [0.0015878607518970966],
#  [0.0016351996455341578],
#  [0.0024895130190998316],
#  [0.002703313250094652],
#  [0.0028012560214847326],
#  [0.0012262646341696382],
#  [0.0020816251635551453],
#  [0.0017108723986893892],
#  [0.0027591411489993334],
#  [0.0034276212099939585],
#  [0.0032455779146403074],
#  [0.0015454486710950732],
#  [0.0024778847582638264],
#  [0.0019220866961404681],
#  [0.002385494066402316],
#  [0.0019663432613015175],
#  [0.003338692942634225],
#  [0.0026367828249931335],
#  [0.0023134176153689623],
#  [0.0024242429062724113],
#  [0.0016193813644349575],
#  [0.0017808870179578662],
#  [0.0019485580269247293],
#  [0.001118220272473991],
#  [0.0010574300540611148],
#  [0.0032302329782396555],
#  [0.002816074760630727],
#  [0.0015342992264777422],
#  [0.004703715443611145],
#  [0.0028098125476390123],
#  [0.001309146056883037],
#  [0.002909932052716613],
#  [0.0024267525877803564],
#  [0.0016258686082437634],
#  [0.002029945608228445],
#  [0.002341051120311022],
#  [0.0024625337682664394],
#  [0.0008889370365068316],
#  [0.0018477750709280372],
#  [0.001608255784958601],
#  [0.0025543055962771177],
#  [0.0038647421170026064],
#  [0.002795057138428092],
#  [0.0026089660823345184],
#  [0.0020265141502022743],
#  [0.0019915958400815725],
#  [0.0018472026567906141],
#  [0.0014373644953593612],
#  [0.006475712638348341],
#  [0.0016512256115674973],
#  [0.0017786266980692744],
#  [0.0038415982853621244],
#  [0.0012424120213836432],
#  [0.001253999536857009],
#  [0.0037855692207813263],
#  [0.003828153247013688],
#  [0.002849730895832181],
#  [0.006283849012106657],
#  [0.0016141152009367943],
#  [0.0007719958666712046],
#  [0.002683933824300766],
#  [0.0031648867297917604],
#  [0.010719217360019684],
#  [0.002212772611528635],
#  [0.0034166621044278145],
#  [0.0032120642717927694],
#  [0.0016964426031336188],
#  [0.001612251391634345],
#  [0.0033643797505646944],
#  [0.0028497956227511168],
#  [0.0009019068675115705],
#  [0.0016272709472104907],
#  [0.00322651956230402],
#  [0.0017449137521907687],
#  [0.003195463214069605],
#  [0.003599367802962661],
#  [0.0014339976478368044],
#  [0.0014973803190514445],
#  [0.004077140707522631],
#  [0.002441675402224064],
#  [0.002015891717746854],
#  [0.0023661747109144926],
#  [0.0032302329782396555],
#  [0.0038112301845103502],
#  [0.0016351996455341578],
#  [0.0024943312164396048],
#  [0.0020475236233323812],
#  [0.0016254289075732231],
#  [0.0016791911330074072],
#  [0.0031565004028379917],
#  [0.0017203775933012366],
#  [0.0031983882654458284],
#  [0.001923904288560152],
#  [0.0019203083356842399],
#  [0.0015628819819539785],
#  [0.001930635655298829],
#  [0.002037151949480176],
#  [0.0019584638066589832],
#  [0.0013896801974624395],
#  [0.00187963736243546],
#  [0.0021847549360245466],
#  [0.0020666057243943214],
#  [0.002391044981777668],
#  [0.0020905709825456142],
#  [0.0023432059679180384],
#  [0.0013871031114831567],
#  [0.0024355461355298758],
#  [0.003211870789527893],
#  [0.0017023455584421754],
#  [0.0028660709504038095],
#  [0.0023786225356161594],
#  [0.0025357420090585947],
#  [0.0029592053033411503],
#  [0.0014973531942814589],
#  [0.005021657329052687],
#  [0.0028242601547390223],
#  [0.0016526969848200679],
#  [0.0026734103448688984],
#  [0.0016185621498152614],
#  [0.0012730967719107866],
#  [0.0027492830995470285],
#  [0.0018221013015136123],
#  [0.0025863845366984606],
#  [0.0015258531784638762],
#  [0.0021458626724779606],
#  [0.0018084783805534244],
#  [0.0026110103353857994],
#  [0.002153301378712058],
#  [0.002020108513534069],
#  [0.0016851432155817747],
#  [0.0024860661942511797],
#  [0.00278834137134254],
#  [0.004533682018518448],
#  [0.0017254475969821215],
#  [0.00219831638969481],
#  [0.002137472853064537],
#  [0.004972785245627165],
#  [0.0020299223251640797],
#  [0.0015952984103932977],
#  [0.0024081040173768997],
#  [0.00214868551120162],
#  [0.005506886634975672],
#  [0.0026613555382937193],
#  [0.0036547814961522818],
#  [0.0011130314087495208],
#  [0.002155508380383253],
#  [0.0024634653236716986],
#  [0.002812204882502556],
#  [0.0030642645433545113],
#  [0.0012507549254223704],
#  [0.00188462866935879],
#  [0.001370440237224102],
#  [0.002081801649183035],
#  [0.004461671691387892],
#  [0.00551719032227993],
#  [0.004461671691387892],
#  [0.0024584410712122917],
#  [0.0024156372528523207],
#  [0.0017544925212860107],
#  [0.0011673109838739038],
#  [0.0007485249661840498],
#  [0.0034553916193544865],
#  [0.002870003692805767],
#  [0.0017527019372209907],
#  [0.005625541787594557],
#  [0.0027612887788563967],
#  [0.002744426717981696],
#  [0.00358361448161304],
#  [0.0018074439140036702],
#  [0.0020268382504582405],
#  [0.002482749056071043],
#  [0.0010957515332847834],
#  [0.0016594754997640848],
#  [0.0016213336493819952],
#  [0.0017808870179578662],
#  [0.002886392641812563],
#  [0.001457040198147297],
#  [0.0036717779003083706],
#  [0.0019887639209628105],
#  [0.0020778595935553312],
#  [0.0015598469180986285],
#  [0.0028726099990308285],
#  [0.003195504192262888],
#  [0.0022166429553180933],
#  [0.0015210820129141212],
#  [0.002549107652157545],
#  [0.00184020702727139],
#  [0.00276710232719779],
#  [0.002421674085780978],
#  [0.0013413362903520465],
#  [0.002233771374449134],
#  [0.0015095314010977745],
#  [0.003187879454344511],
#  [0.0014450792223215103],
#  [0.0033576202113181353],
#  [0.0037254677154123783],
#  [0.0012897489359602332],
#  [0.0021582022309303284],
#  [0.002148618921637535],
#  [0.002048665890470147],
#  [0.007264682557433844],
#  [0.0013598994119092822],
#  [0.0023631644435226917],
#  [0.0013341575395315886],
#  [0.0012066338676959276],
#  [0.0021857968531548977],
#  [0.0010058062616735697],
#  [0.0025486433878540993],
#  [0.001217897399328649],
#  [0.0030499743297696114],
#  [0.0028044625651091337],
#  [0.002098832046613097],
#  [0.0022835657000541687],
#  [0.004132580477744341],
#  [0.0021704372484236956],
#  [0.0024867532774806023],
#  [0.0011223925976082683],
#  [0.0034252633340656757],
#  [0.002128640655428171],
#  [0.0017114098882302642],
#  [0.001524301478639245],
#  [0.0025622304528951645],
#  [0.002032533986493945],
#  [0.001825439860112965],
#  [0.0022350172512233257],
#  [0.002812009770423174],
#  [0.002029760042205453],
#  [0.0021857968531548977],
#  [0.0036800033412873745],
#  [0.0027184425853192806],
#  [0.002906982321292162],
#  [0.0017764474032446742],
#  [0.0032146151643246412],
#  [0.001415610546246171],
#  [0.003542394144460559],
#  [0.0025138824712485075],
#  [0.0012685577385127544],
#  [0.0023553138598799706],
#  [0.003739846870303154],
#  [0.0014860753435641527],
#  [0.0022279485128819942],
#  [0.002624362474307418],
#  [0.004664557985961437],
#  [0.002305389614775777],
#  [0.002545882249251008],
#  [0.0031372879166156054],
#  [0.001198599231429398],
#  [0.00400446355342865],
#  [0.0025844343472272158],
#  [0.0024374653585255146],
#  [0.0025847649667412043],
#  [0.002099917735904455],
#  [0.001967370044440031],
#  [0.002240526955574751],
#  [0.0029410545248538256],
#  [0.0021647214889526367],
#  [0.0032626294996589422],
#  [0.0017292849952355027],
#  [0.002045139903202653],
#  [0.002310990821570158],
#  [0.0018979875603690743],
#  [0.001466046436689794],
#  [0.003726685419678688],
#  [0.0024121522437781096],
#  [0.002155508380383253],
#  [0.0014951463090255857],
#  [0.0013726138276979327],
#  [0.002327871974557638],
#  [0.003929740283638239],
#  [0.0032045692205429077],
#  [0.005066193174570799],
#  [0.0015354311326518655],
#  [0.002971286652609706],
#  [0.0013315356336534023],
#  [0.0024268401321023703],
#  [0.0009995130822062492],
#  [0.0016970952274277806],
#  [0.002707286039367318],
#  [0.001452444470487535],
#  [0.003379093948751688],
#  [0.0039017791859805584],
#  [0.0018876924877986312],
#  [0.0025450661778450012],
#  [0.005534909665584564],
#  [0.002540848683565855],
#  [0.0036544897593557835],
#  [0.0023592968937009573],
#  [0.002155508380383253],
#  [0.0036717779003083706],
#  [0.0019389698281884193],
#  [0.0019431510008871555],
#  [0.0017132065258920193],
#  [0.0035446500405669212],
#  [0.0022233889903873205],
#  [0.004849607590585947],
#  [0.0018916045082733035],
#  [0.0022139339707791805],
#  [0.0026180059649050236],
#  [0.0077615357004106045],
#  [0.0012692363234236836],
#  [0.0027335744816809893],
#  [0.0014080904657021165],
#  [0.003058232367038727],
#  [0.002141438890248537],
#  [0.0009813009528443217],
#  [0.001380440779030323],
#  [0.0018812052439898252],
#  [0.0021401462145149708],
#  [0.0013789493823423982],
#  [0.002381132449954748],
#  [0.002477894304320216],
#  [0.0020296780858188868],
#  [0.0012468029744923115],
#  [0.005912615917623043],
#  [0.008809776976704597],
#  [0.0071755400858819485],
#  [0.010116568766534328],
#  [0.004860712680965662],
#  [0.00684254290536046],
#  [0.0052453638054430485],
#  [0.004733719397336245],
#  [0.003577479626983404],
#  [0.005408197641372681],
#  [0.005499360617250204],
#  [0.004531147424131632],
#  [0.004281029105186462],
#  [0.0019254348007962108],
#  [0.005344252102077007],
#  [0.003820298705250025],
#  [0.005677410401403904],
#  [0.0050128428265452385],
#  [0.0038162085693329573],
#  [0.00443373154848814],
#  [0.004628619644790888],
#  [0.004290680401027203],
#  [0.005639792885631323],
#  [0.0044786687940359116],
#  [0.005843945778906345],
#  [0.003769105998799205],
#  [0.008510928601026535],
#  [0.006104168947786093],
#  [0.00393736083060503],
#  [0.004371327813714743],
#  [0.0050039435736835],
#  [0.01636550761759281],
#  [0.014084667898714542],
#  [0.018886135891079903],
#  [0.02023255079984665],
#  [0.01662629470229149],
#  [0.01127236895263195],
#  [0.008231518790125847],
#  [0.02870604768395424],
#  [0.002227291464805603],
#  [0.0072109452448785305],
#  [0.01786149851977825],
#  [0.006997308228164911],
#  [0.009195909835398197],
#  [0.0059464420191943645],
#  [0.007804811000823975],
#  [0.0025948453694581985],
#  [0.002641711849719286],
#  [0.005529907066375017],
#  [0.0077918050810694695],
#  [0.005741191562265158],
#  [0.0074649169109761715],
#  [0.007705361116677523],
#  [0.01203194260597229],
#  [0.009227300062775612],
#  [0.010221458971500397],
#  [0.010946239344775677],
#  [0.00902296882122755],
#  [0.004451668821275234],
#  [0.008907847106456757],
#  [0.01075572706758976],
#  [0.008464647457003593],
#  [0.013131944462656975],
#  [0.010431290604174137],
#  [0.007545445114374161],
#  [0.008454644121229649],
#  [0.005462924018502235],
#  [0.010861217975616455],
#  [0.0047161392867565155],
#  [0.004781755618751049],
#  [0.008975867182016373],
#  [0.020323632284998894],
#  [0.005852376576513052],
#  [0.013913947157561779],
#  [0.012923009693622589],
#  [0.009238981641829014],
#  [0.02732170559465885],
#  [0.010758512653410435],
#  [0.03516151383519173],
#  [0.014308144338428974],
#  [0.008039950393140316],
#  [0.01846361719071865],
#  [0.00471973093226552],
#  [0.005315812304615974],
#  [0.023836294189095497],
#  [0.011350857093930244],
#  [0.011421401984989643],
#  [0.008909943513572216],
#  [0.003281738143414259],
#  [0.004870251752436161],
#  [0.003951537422835827],
#  [0.0029745008796453476],
#  [0.005595069378614426],
#  [0.0031107603572309017],
#  [0.0035776414442807436],
#  [0.005206277593970299],
#  [0.023002872243523598],
#  [0.03340122103691101],
#  [0.024652967229485512],
#  [0.017167117446660995],
#  [0.009286710061132908],
#  [0.008498540148139],
#  [0.007391957566142082],
#  [0.013240016996860504],
#  [0.004110653419047594],
#  [0.012480417266488075],
#  [0.0034939059987664223],
#  [0.009782804176211357],
#  [0.007759456988424063],
#  [0.0027498218696564436],
#  [0.00795952882617712],
#  [0.02929914928972721],
#  [0.042647834867239],
#  [0.035172369331121445],
#  [0.00806510727852583],
#  [0.039586521685123444],
#  [0.051281288266181946],
#  [0.04770592227578163],
#  [0.026151051744818687],
#  [0.035215824842453],
#  [0.02703491598367691],
#  [0.03671569749712944],
#  [0.043599195778369904],
#  [0.0383383110165596],
#  [0.025643499568104744],
#  [0.040929995477199554],
#  [0.029752302914857864],
#  [0.013789941556751728],
#  [0.00924217700958252],
#  [0.00701042078435421],
#  [0.01407976821064949],
#  [0.010359568521380424],
#  [0.008866455405950546],
#  [0.009741663932800293],
#  [0.010343174450099468],
#  [0.008072874508798122],
#  [0.004979207180440426],
#  [0.005972208455204964],
#  [0.0041928342543542385],
#  [0.003177155740559101],
#  [0.013697625137865543],
#  [0.01180476788431406],
#  [0.014085005037486553],
#  [0.007830934599041939],
#  [0.00598252983763814],
#  [0.004344636108726263],
#  [0.009064343757927418],
#  [0.0017222883179783821],
#  [0.0049646166153252125],
#  [0.00591090926900506],
#  [0.005527096800506115],
#  [0.006856663152575493],
#  [0.046869851648807526],
#  [0.05230387672781944],
#  [0.03099977597594261],
#  [0.03188919648528099],
#  [0.04467056319117546],
#  [0.019154701381921768],
#  [0.03403143584728241],
#  [0.013971605338156223],
#  [0.011299729347229004],
#  [0.009156357496976852],
#  [0.015259087085723877],
#  [0.010734504088759422],
#  [0.018510760739445686],
#  [0.02044805698096752],
#  [0.015004581771790981],
#  [0.008181624114513397],
#  [0.02857469953596592],
#  [0.008681289851665497],
#  [0.008176715113222599],
#  [0.0032299919985234737],
#  [0.008785231970250607],
#  [0.02197696454823017],
#  [0.0006474917172454298],
#  [0.018995648249983788],
#  [0.008015037514269352],
#  [0.018397103995084763],
#  [0.010678090155124664],
#  [0.026945196092128754],
#  [0.006176740862429142],
#  [0.00907672569155693],
#  [0.008692866191267967],
#  [0.014001065865159035],
#  [0.012492187321186066],
#  [0.01915109157562256],
#  [0.007155000697821379],
#  [0.0147653603926301],
#  [0.014194341376423836],
#  [0.00870433822274208],
#  [0.00906931422650814],
#  [0.025899967178702354],
#  [0.01034407876431942],
#  [0.004499791655689478],
#  [0.01566995121538639],
#  [0.00794729683548212],
#  [0.00806671753525734],
#  [0.00424257991835475],
#  [0.020398659631609917],
#  [0.019872989505529404],
#  [0.008126948960125446],
#  [0.01624535582959652],
#  [0.008021307177841663],
#  [0.015813885256648064],
#  [0.01091493759304285],
#  [0.007466637529432774],
#  [0.010293682105839252],
#  [0.00863991305232048],
#  [0.01259716134518385],
#  [0.007714652922004461],
#  [0.017195452004671097],
#  [0.02442706748843193],
#  [0.01747422106564045],
#  [0.008422509767115116],
#  [0.010909004136919975],
#  [0.008938862942159176],
#  [0.016555769369006157],
#  [0.01346095371991396],
#  [0.007424614857882261],
#  [0.0007860849145799875],
#  [0.0173674114048481],
#  [0.004863739479333162],
#  [0.014194341376423836],
#  [0.013822820037603378],
#  [0.0033897992689162493],
#  [0.018892405554652214],
#  [0.010278531350195408],
#  [0.01217900775372982],
#  [0.019197292625904083],
#  [0.017069734632968903],
#  [0.018397103995084763],
#  [0.02104830928146839],
#  [0.016968781128525734],
#  [0.008636335842311382],
#  [0.011264118365943432],
#  [0.013374816626310349],
#  [0.010576055385172367],
#  [0.017263611778616905],
#  [0.003771968185901642],
#  [0.010687973350286484],
#  [0.008273948915302753],
#  [0.025342511013150215],
#  [0.013589505106210709],
#  [0.013557391241192818],
#  [0.01967662014067173],
#  [0.013575871475040913],
#  [0.015392792411148548],
#  [0.01173936016857624],
#  [0.0034068904351443052],
#  [0.011240771040320396],
#  [0.004483903758227825],
#  [0.022006766870617867],
#  [0.005452772602438927],
#  [0.017786962911486626],
#  [0.016481881961226463],
#  [0.009895087219774723],
#  [0.0049653188325464725],
#  [0.021428465843200684],
#  [0.016000142320990562],
#  [0.007648443337529898],
#  [0.0046511259861290455],
#  [0.011794038116931915],
#  [0.01190078817307949],
#  [0.009935630485415459],
#  [0.020398659631609917],
#  [0.006785264704376459],
#  [0.015253491699695587],
#  [0.007963004522025585],
#  [0.01936112716794014],
#  [0.007335017900913954],
#  [0.01173936016857624],
#  [0.007046451326459646],
#  [0.011905038729310036],
#  [0.0050057293847203255],
#  [0.017270158976316452],
#  [0.014202804304659367],
#  [0.01876310631632805],
#  [0.013426877558231354],
#  [0.007864657789468765],
#  [0.017450446262955666],
#  [0.014116387814283371],
#  [0.010626490227878094],
#  [0.013433978892862797],
#  [0.005708137061446905],
#  [0.02086137793958187],
#  [0.01082155667245388],
#  [0.017707744613289833],
#  [0.007672849111258984],
#  [0.018926521763205528],
#  [0.005238747224211693],
#  [0.012065630406141281],
#  [0.011533970944583416],
#  [0.015594104304909706],
#  [0.01209330279380083],
#  [0.007616516202688217],
#  [0.021204635500907898],
#  [0.013161900453269482],
#  [0.00949831958860159],
#  [0.013209588825702667],
#  [0.006682983133941889],
#  [0.02155342325568199],
#  [0.025777403265237808],
#  [0.018942607566714287],
#  [0.009591071866452694],
#  [0.017516253516077995],
#  [0.010967922396957874],
#  [0.025021284818649292],
#  [0.011427724733948708],
#  [0.013106479309499264],
#  [0.010740921832621098],
#  [0.008814387023448944],
#  [0.016017531976103783],
#  [0.013357579708099365],
#  [0.01040684524923563],
#  [0.01658066362142563],
#  [0.014228946529328823],
#  [0.0013068856205791235],
#  [0.027926141396164894],
#  [0.014762794598937035],
#  [0.017195289954543114],
#  [0.012805115431547165],
#  [0.02399485744535923],
#  [0.0035810358822345734],
#  [0.014968127012252808],
#  [0.0026996033266186714],
#  [0.012393143028020859],
#  [0.01173936016857624],
#  [0.011697842739522457],
#  [0.022812072187662125],
#  [0.019323373213410378],
#  [0.01766141504049301],
#  [0.011627819389104843],
#  [0.01934964954853058],
#  [0.007637929171323776],
#  [0.013650310225784779],
#  [0.011500237509608269],
#  [0.011583148501813412],
#  [0.010433322750031948],
#  [0.029427427798509598],
#  [0.006181994918733835],
#  [0.011791015043854713],
#  [0.010966852307319641],
#  [0.011293753981590271],
#  [0.012624474242329597],
#  [0.008158466778695583],
#  [0.008334513753652573],
#  [0.01882864534854889],
#  [0.009363260120153427],
#  [0.0021685564424842596],
#  [0.022006766870617867],
#  [0.017516449093818665],
#  [0.0035121559631079435],
#  [0.006948762107640505],
#  [0.020121444016695023],
#  [0.010518648661673069],
#  [0.008970003575086594],
#  [0.009330331347882748],
#  [0.010723293758928776],
#  [0.011081996373832226],
#  [0.01016002893447876],
#  [0.026649847626686096],
#  [0.010681587271392345],
#  [0.01822652481496334],
#  [0.007659674622118473],
#  [0.010581775568425655],
#  [0.019386474043130875],
#  [0.012732918374240398],
#  [0.019662687554955482],
#  [0.008782877586781979],
#  [0.00820109061896801],
#  [0.023387519642710686],
#  [0.006660080049186945],
#  [0.005716006737202406],
#  [0.010069556534290314],
#  [0.013366657309234142],
#  [0.00993389543145895],
#  [0.006485463585704565],
#  [0.024011695757508278],
#  [0.014774159528315067],
#  [0.009343289770185947],
#  [0.018942607566714287],
#  [0.015112179331481457],
#  [0.006262366659939289],
#  [0.016017531976103783],
#  [0.01256969477981329],
#  [0.0044733379036188126],
#  [0.007071119733154774],
#  [0.011051295325160027],
#  [0.00842787604779005],
#  [0.020917586982250214],
#  [0.015349564142525196],
#  [0.017770199105143547],
#  [0.018003445118665695],
#  [0.01880306378006935],
#  [0.006451757159084082],
#  [0.011438206769526005],
#  [0.015994349494576454],
#  [0.016027064993977547],
#  [0.00367625686340034],
#  [0.009895087219774723],
#  [0.01946266181766987],
#  [0.01636718213558197],
#  [0.01644149050116539],
#  [0.01165113877505064],
#  [0.02568698488175869],
#  [0.006053968798369169],
#  [0.014563343487679958],
#  [0.010580682195723057],
#  [0.013403274118900299],
#  [0.02294379286468029],
#  [0.00945219211280346],
#  [0.015031011775135994],
#  [0.017925744876265526],
#  [0.012026281096041203],
#  [0.013953505083918571],
#  [0.015456752851605415],
#  [0.01038552075624466],
#  [0.010799406096339226],
#  [0.011601658537983894],
#  [0.0256523285061121],
#  [0.006174200680106878],
#  [0.018942607566714287],
#  [0.006661843508481979],
#  [0.02097412198781967],
#  [0.02097412198781967],
#  [0.007185925729572773],
#  [0.019787415862083435],
#  [0.009333898313343525],
#  [0.0145803177729249],
#  [0.01532859168946743],
#  [0.019815828651189804],
#  [0.021922621876001358],
#  [0.010215841233730316],
#  [0.01640852726995945],
#  [0.008494346402585506],
#  [0.019386691972613335],
#  [0.006893465761095285],
#  [0.013051779940724373],
#  [0.027785394340753555],
#  [0.01147072110325098],
#  [0.008834836073219776],
#  [0.006503561045974493],
#  [0.016017531976103783],
#  [0.022377770394086838],
#  [0.016017531976103783],
#  [0.010545865632593632],
#  [0.005367161240428686],
#  [0.016064442694187164],
#  [0.011427724733948708],
#  [0.006253402214497328],
#  [0.013572071678936481],
#  [0.019872989505529404],
#  [0.01650468446314335],
#  [0.011341304518282413],
#  [0.008205908350646496],
#  [0.012034783139824867],
#  [0.0063473847694695],
#  [0.006973995361477137],
#  [0.038455620408058167],
#  [0.009221304208040237],
#  [0.010678090155124664],
#  [0.010695538483560085],
#  [0.011823305860161781],
#  [0.017827793955802917],
#  [0.024716602638363838],
#  [0.011529132723808289],
#  [0.011924906633794308],
#  [0.0059546977281570435],
#  [0.01293917465955019],
#  [0.007879569195210934],
#  [0.011459674686193466],
#  [0.014426243491470814],
#  [0.0005637403228320181],
#  [0.015664368867874146],
#  ...]

# %%
Y_pre = (model_lgb.predict_proba(X_pre)[:,1]+model_xgb.predict_proba(X_pre)[:,1])/2
Y_pre = Y_pre.reshape(-1,1)
Y_prelist = Y_pre.tolist()

# %%
# sub = pd.DataFrame()
# sub['instance_id'] = np.array(data2[['instance_id']],dtype='float').ravel()
# sub['predicted_score'] = Y_pre[:,1].ravel()
# sub.to_csv('submission.csv',index=False)

# %%
instance_id = np.array(data2[['instance_id']],dtype='float').ravel()
instance_idlist = instance_id.tolist()
with open('111.txt', 'w') as f:
    f.write("instance_id predicted_score\r") 
    for i in range(Y_pre.shape[0]):
        f.write(str(data2[['instance_id']].iloc[i,0]) + " " + str(Y_pre[i][0]) + '\r') 
#         f.write(str(data2[['instance_id']].iloc[i,0]) + " " + str('%.15f'%Y_pre[i,0]) + '\r')

# %%
Y_pre.shape[0]
# Out:
# 18371

# %%
np.set_printoptions(suppress=True)

# %%
'%.15f'%Y_pre[0,0]
# Out:
# '0.000002709476912'

# %%
# data2[['instance_id']]

# %%
# sub = pd.DataFrame()
# sub['instance_id'] = data2.pop('instance_id')
# sub['predicted_score'] = Y_pre[:,1].ravel().reshape(-1, 1)
# sub.to_csv('000.txt',index=False, sep=' ')
